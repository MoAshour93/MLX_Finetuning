# %% [markdown]
# # Finetuning on Mac - Updated February 2025
#
# ### Disclaimer:
# These steps are created after having a very thorough read of the following:
# * The MLX community - https://github.com/ml-explore/mlx-examples/blob/main/llms/mlx_lm/LORA.md
# * Andy Peating articles:
#     * Part 1 - Setting up your environment- https://apeatling.com/articles/part-1-setting-up-your-environment/
#     * Part 2 - Building your training data for fine-tuning  https://apeatling.com/articles/part-2-building-your-training-data-for-fine-tuning/
#     * Part 3 - Fine-tuning your llm using the mlx framework https://apeatling.com/articles/part-3-fine-tuning-your-llm-using-the-mlx-framework/
#     * Part 4- Testing and interacting with your fine-tuned LLM  https://apeatling.com/articles/part-4-testing-and-interacting-with-your-fine-tuned-llm/
# * Llama 3 Model cards and prompting format available through : https://www.llama.com/docs/model-cards-and-prompt-formats/meta-llama-3/
# * Fine-tuning LLMs on Mac OS using MLX and run with Ollama - https://medium.com/rahasak/fine-tuning-llms-on-macos-using-mlx-and-run-with-ollama-182a20f1fd2c
#
# Please note that different models have different model cards and prompting templates and you should visit the developer of every LLM to tweak the code to account for the relevant chat template.

# %% [markdown]
# # Part I - Setting up the coding environment
#
# 1. Open terminal in your preferred location on your Mac. You can do that by opening finder and then if you have the path bar enabled, you can go to your preferred location, right click on the path bar and then choose open in terminal.
#
# 2. install home-brew from “https://brew.sh/“ where you have to paste the following code in terminal
#
#              /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
#
# 3. Make sure that your home-brew is on your PATH by typing on the following commands in your opened terminal window:
#
#             echo >> /Users/{Your_Username}/.zprofile
#
#             echo 'eval "$(/opt/homebrew/bin/brew shellenv)"' >> /Users/{Your_Username}/.zprofile
#
#             eval "$(/opt/homebrew/bin/brew shellenv)"
#
# 4. Install git using the code “brew install git” in your terminal window. You can have more details from the git website: https://git-scm.com/downloads/mac
#
# 5. Clone the mlx repository through the following code in your terminal window:
#
#             git clone https://github.com/ml-explore/mlx-examples.git
#
# 6. change the directory to go inside the lora folder which is located inside the mlx-examples folder through the following command in your terminal window:
#
#             cd mlx-examples/lora
#
# 7. Make sure to have python installed on your machine. You can go to the website “https://www.python.org/downloads/macos/“ and download your preferred version. I would recommend a version that is 3.11 and later.
#
# 8. Make sure to have pip installed on your machine. If in doubt you can install it using the following command in your terminal
#
#              Python -m ensurepip —upgrade
#
#              OR
#
#              Python3 -m ensurepip —upgrade
#
# 9. Following from step 5, having changed the directory to be inside the lora folder, we can now Install the requirements  by typing the following command in your terminal
#
#             Pip install -r requirements.txt
#
#             OR
#
#             pip3 install -r requirements.txt
#
# 10. The MLX LoRA fine-tuning is quite efficient for accounting for the required data, fine-tuning the model and fusing the original model with the trained adapters.
#
#     However when it comes to converting the safetensors of the fine-tuned model to GGUF for further usage on Ollama or Open WebUI or other 3rd party apps, it is mandatory to use the llama.cpp
#
#     The mlx_lm.convert doesnot provide multiple options for quantization, the default is 16bit. This is valid up to February 2025. This can change in future releases.
#
#     You can clone the llama.cpp respository which can be through the following link. The code is as follows:
#
#             git clone https://github.com/ggerganov/llama.cpp.git
#
#     Then later on in this code, we would need to change the working directory to be inside the cloned llama.cpp on our machine to be able to use the convert_hf_to_gguf.py file for model conversion from safetensors to GGUF with the required quantization.

# %% [markdown]
# # Part II - Create/Import  and Edit data for fine-tuning:
#
# 10. Create your training data for fine-tuning:
#
#     1. This is going to be done outside of the terminal environment. For the purpose of this example, I have a csv file containing the questions and answers of RICS APC submissions in the form of questions and answers. The file is composed of 3 columns “id”, “question” & “answer.
#
#     2. Every model has its chat template, for the current example, we are going to use the mistral  architecture. I used a chat template that was proposed by the MLX team on their github repository which works fine for the mistral architecture
#
#                 {"messages": [{"role": "system", "content": "You are a helpful assistant."}, {"role": "user", "content": "Hello."}, {"role": "assistant", "content": "How can I assistant you today."}]}
#
#         In future fine-tuning I will use the official chat template of mistral which you can find below:
#
#                 <s>[INST] Human message [/INST] Assistant response </s>[INST] Human message [/INST] Assistant response
#
#     3. For fine-tuning purposes using the MLX library, we have to convert the training data into 3 json files: “train.jsonl”, ”test.jsonl” & “valid.jsonl”
#
#     4. I built a python code which takes the csv uploaded by the end user from any desired location and then it applies the llama 3 chat template on it and then saves the training, testing and validation files in jsonl format.
#
#         The training data is 80% of the original data size, testing is at 10% and validation is at 10%. All the resultant files are saved in a folder called data
#
#         In case of gated models, you will have to install huggingface hub in terminal using
#
#                 Pip install huggingface_hub
#
#                 OR
#
#                 Pip3 install huggingface_hub
#
#         This should be followed by logging into your account using your token by typing the following code in your terminal window
#
#                 Huggingface-cli login —token {Your_token}

# %% [markdown]
# # Part III - Training your model, testing and validation:

# %% [markdown]
# ### Step 3.1: Defining important Variables

# %%
#Defining the necessary directories for the models, the adapters and the data

# This code block is quite important as I am defining the different variables that I am go to use through my code.
# You can change them to suit your needs.
# The variables include the following:
# 1. Data directory - The location where the train.jsonl, the test.jsonl and the valid.jsonl files are saved
# 2. Downloaded Huggingface Model directory - In my case it is the Mistal Instruct v0.3 with 16 bits accuracy
# 3. Huggingface repository - In my case it is the Mistal Instruct v0.3 with 16 bits accuracy
# 4. My desired Huggingface repository name for saving the fine-tuned model
# 5. A write-token created from the Huggingface website to able to interact with the site to upload and download models.
# 6. A directory for the place where I want to save the converted model from the huggingface format to MLX format
# 7. The Desired name for the fine-tuned MLX model
# 8. The output directory for the fine-tuned MLX model
# 9. Llama.cpp directory where I cloned the github repository to be able to use it in terminal under this jupyter notebook.


data=#Input your data directory here
downloaded_hf_model=#Input the directory where you want to download your desired Huggingface Model
hf_model = "mistralai/Mistral-7B-Instruct-v0.3" #Change as needed
hf_token=#Input your Huggingface Write-Token
hf_upload_repo=#Enter your username on HF followed by the desired name of the repository for your fine-tuned model
mlx_path=#Input the directory where you want to download your MLX converted model
adapters=#Input the directory where you want to save your LoRA adapters
output_directory=#Input the directory where you want to save your MLX fine-tuned model
Desired_model_name=#Enter the desired name of the model as required
System_prompt= f"""
You are an AI language model specialized in providing detailed, accurate, and professional responses to questions related to the RICS Assessment of Professional Competence (APC). Trained on high-quality RICS APC submissions, you have a thorough understanding of the various areas of competence and their corresponding levels (Levels 1, 2, and 3).

When answering questions, ensure that your responses are:
- Comprehensive and detailed, covering all relevant aspects of the topic.
- Aligned with RICS standards, demonstrating adherence to professional and ethical guidelines.
- Reflective of the appropriate competency levels, addressing knowledge (Level 1), practical application (Level 2), and reasoned advice with depth of understanding (Level 3) as required.
- Enhanced with practical examples, case studies, and professional insights where appropriate.
- Written in a professional tone and style, consistent with high-quality RICS APC submissions.

Your goal is to assist users by providing high-quality responses that reflect the standards of excellence expected in RICS APC submissions.
""" ###Change as needed.
llama_cpp_path=#Enter the directory where you have cloned the llama.cpp

# !hf auth login --token {hf_token}
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# The token `mac_os_LLM_Finetuning` has been saved to /Users/mohamedraouf/.cache/huggingface/stored_tokens
# Your token has been saved to /Users/mohamedraouf/.cache/huggingface/token
# Login successful.
# The current active token is: `mac_os_LLM_Finetuning`

# %% [markdown]
# ### Step 3.2: Downloading the desired model from the Huggingface

# %%
#This step is quite important to enable downloading models from the huggingface website to your local storage for further use.

# !hf auth login --token {hf_token}

# !hf download --repo-type model --local-dir {downloaded_hf_model} {hf_model}
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# The token `mac_os_LLM_Finetuning` has been saved to /Users/mohamedraouf/.cache/huggingface/stored_tokens
# Your token has been saved to /Users/mohamedraouf/.cache/huggingface/token
# Login successful.
# The current active token is: `mac_os_LLM_Finetuning`
# Fetching 15 files:   0%|                                 | 0/15 [00:00<?, ?it/s]Still waiting to acquire lock on /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Downloading 'config.json' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.9f913dc05d66cfb23c16e3c93b3cc4899813dfa6.incomplete'
# Downloading 'model-00003-of-00003.safetensors' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/NmVQgThqhsRkG2FlXLh-M51MilA=.905dd405363e43d95779c1c1155a2dbfd36155914ae95dbd934e12e490cfb4ca.incomplete'
# Downloading 'model-00001-of-00003.safetensors' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/Y6g195DXbsCiN_Ka1NwH6jyLkvc=.ce6fb6f6f4d0183f4813cbf4ece24109da629a08d4210da46f77e1d8b0bd5c19.incomplete'
# Downloading 'generation_config.json' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/3EVKVggOldJcKSsGjSdoUCN1AyQ=.b6bea2642bc3fe80f392111d52af91d1563a8de2.incomplete'
# Downloading '.gitattributes' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.a6344aac8c09253b3b630fb776ae94478aa0275b.incomplete'
#
# model-00001-of-00003.safetensors:   0%|             | 0.00/4.95G [00:00<?, ?B/s]Downloading 'model-00002-of-00003.safetensors' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/D5-QTaCbl9VUFv9Wr0C28eFewRc=.8c0e72f148366b6a3709e002a98706a33d31aec8515090c856c95b2044f92ae0.incomplete'
# Downloading 'README.md' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.3de69a2ba44943bc3ced2181225a3a9a228634a6.incomplete'
# Downloading 'consolidated.safetensors' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/tFt5id3gCLBzpax0WVpbeEjTCck=.76d5729be995fb6510c7f103c5b8825d3d82f8126ac949db6be367a638694d1f.incomplete'
#
#
# config.json: 100%|█████████████████████████████| 601/601 [00:00<00:00, 7.62MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/config.json
#
#
# model-00002-of-00003.safetensors:   0%|             | 0.00/5.00G [00:00<?, ?B/s]
#
#
# generation_config.json: 100%|██████████████████| 116/116 [00:00<00:00, 1.84MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/generation_config.json
#
#
#
# model-00003-of-00003.safetensors:   0%|             | 0.00/4.55G [00:00<?, ?B/s]
#
#
#
# .gitattributes: 100%|██████████████████████| 1.52k/1.52k [00:00<00:00, 17.9MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.gitattributes
# Fetching 15 files:   7%|█▋                       | 1/15 [00:00<00:04,  3.36it/s]Downloading 'model.safetensors.index.json' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/yVzAsSxRSINSz-tQbpx-TLpfkLU=.050e5515d49376fc01e4837d031902c63af98111.incomplete'
#
#
#
#
# README.md: 100%|███████████████████████████| 7.82k/7.82k [00:00<00:00, 32.4MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/README.md
#
#
#
#
# consolidated.safetensors:   0%|                     | 0.00/14.5G [00:00<?, ?B/s]Downloading 'params.json' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/jqHB00sRqBVJXCrFOHz5gDS2Bg8=.00dc7d10b86d793afaf3d6733a45ee4d8c557194.incomplete'
#
# model-00001-of-00003.safetensors:   0%|    | 10.5M/4.95G [00:00<02:10, 37.9MB/s]
#
#
#
#
# model.safetensors.index.json: 100%|████████| 23.9k/23.9k [00:00<00:00, 87.4MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/model.safetensors.index.json
# Downloading 'tokenizer.json' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.8d7d23136b474a3df1182ed829db19984e295ee7.incomplete'
#
#
#
#
#
# params.json: 100%|█████████████████████████████| 202/202 [00:00<00:00, 2.12MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/params.json
# Downloading 'special_tokens_map.json' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.451134b2ddc2e78555d1e857518c54b4bdc2e87d.incomplete'
#
#
# model-00002-of-00003.safetensors:   0%|    | 10.5M/5.00G [00:00<02:58, 28.0MB/s]Downloading 'tokenizer.model.v3' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/NZSLRqzbESM_qQvx7b07KAIZrbU=.d8233e5b061987d32b63dbfb38fe86d7d4fc8a18.incomplete'
#
#
#
#
#
# special_tokens_map.json: 100%|█████████████████| 414/414 [00:00<00:00, 6.46MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/special_tokens_map.json
#
#
#
#
#
# tokenizer.model.v3:   0%|                            | 0.00/587k [00:00<?, ?B/s]
#
#
#
#
#
# tokenizer.json:   0%|                               | 0.00/1.96M [00:00<?, ?B/s]Downloading 'tokenizer_config.json' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.940a9c375c745ccbf0bebc5bedcec924d71827aa.incomplete'
# Downloading 'tokenizer.model' to '/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/.cache/huggingface/download/7iVfz3cUOMr-hyjiqqRDHEwVBAM=.37f00374dea48658ee8f5d0f21895b9bc55cb0103939607c8185bfd1c6ca1f89.incomplete'
#
# model-00001-of-00003.safetensors:   0%|    | 21.0M/4.95G [00:00<02:41, 30.5MB/s]
#
# model-00002-of-00003.safetensors:   0%|    | 21.0M/5.00G [00:00<02:28, 33.4MB/s]
#
#
#
#
#
#
# tokenizer_config.json:   0%|                         | 0.00/141k [00:00<?, ?B/s]
#
#
#
#
#
#
#
# tokenizer_config.json: 100%|█████████████████| 141k/141k [00:00<00:00, 1.95MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/tokenizer_config.json
#
#
#
#
#
# tokenizer.model.v3: 100%|████████████████████| 587k/587k [00:00<00:00, 1.74MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/tokenizer.model.v3
#
#
# model-00002-of-00003.safetensors:   1%|    | 31.5M/5.00G [00:00<02:24, 34.3MB/s]
# model-00001-of-00003.safetensors:   1%|    | 31.5M/4.95G [00:01<02:50, 28.8MB/s]
#
#
#
#
#
#
#
# tokenizer.model: 100%|███████████████████████| 587k/587k [00:00<00:00, 2.29MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/tokenizer.model
#
#
#
# model-00003-of-00003.safetensors:   0%|    | 10.5M/4.55G [00:01<08:53, 8.50MB/s]
#
# model-00002-of-00003.safetensors:   1%|    | 41.9M/5.00G [00:01<02:26, 33.8MB/s]
#
#
#
#
#
# tokenizer.json: 100%|██████████████████████| 1.96M/1.96M [00:00<00:00, 2.50MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/tokenizer.json
#
# model-00001-of-00003.safetensors:   1%|    | 41.9M/4.95G [00:01<02:57, 27.7MB/s]
#
# model-00002-of-00003.safetensors:   1%|    | 52.4M/5.00G [00:01<02:22, 34.8MB/s]
# model-00001-of-00003.safetensors:   1%|    | 52.4M/4.95G [00:01<02:47, 29.2MB/s]
#
# model-00002-of-00003.safetensors:   1%|    | 62.9M/5.00G [00:01<02:21, 34.9MB/s]
# model-00001-of-00003.safetensors:   1%|    | 62.9M/4.95G [00:02<02:44, 29.8MB/s]
#
# model-00002-of-00003.safetensors:   1%|    | 73.4M/5.00G [00:02<02:20, 35.2MB/s]
#
#
# model-00003-of-00003.safetensors:   0%|    | 21.0M/4.55G [00:02<08:31, 8.84MB/s]
# model-00001-of-00003.safetensors:   1%|    | 73.4M/4.95G [00:02<03:06, 26.2MB/s]
#
# model-00002-of-00003.safetensors:   2%|    | 83.9M/5.00G [00:02<02:38, 30.9MB/s]
# model-00001-of-00003.safetensors:   2%|    | 83.9M/4.95G [00:02<02:57, 27.4MB/s]
#
# model-00002-of-00003.safetensors:   2%|    | 94.4M/5.00G [00:02<02:41, 30.3MB/s]
#
# model-00002-of-00003.safetensors:   2%|     | 105M/5.00G [00:03<02:39, 30.7MB/s]
# model-00001-of-00003.safetensors:   2%|    | 94.4M/4.95G [00:03<03:13, 25.1MB/s]
#
# model-00002-of-00003.safetensors:   2%|     | 115M/5.00G [00:03<02:29, 32.6MB/s]
#
#
# model-00003-of-00003.safetensors:   1%|    | 31.5M/4.55G [00:03<08:56, 8.42MB/s]
#
# model-00002-of-00003.safetensors:   3%|▏    | 126M/5.00G [00:03<02:19, 34.9MB/s]
# model-00001-of-00003.safetensors:   2%|     | 105M/4.95G [00:03<03:13, 25.1MB/s]
#
#
#
# consolidated.safetensors:   0%|          | 10.5M/14.5G [00:03<1:25:50, 2.81MB/s]
#
# model-00002-of-00003.safetensors:   3%|▏    | 136M/5.00G [00:04<02:18, 35.1MB/s]
#
# model-00002-of-00003.safetensors:   3%|▏    | 147M/5.00G [00:04<02:03, 39.2MB/s]
# model-00001-of-00003.safetensors:   2%|     | 115M/4.95G [00:04<03:21, 23.9MB/s]
#
# model-00002-of-00003.safetensors:   3%|▏    | 157M/5.00G [00:04<01:59, 40.4MB/s]
#
#
# model-00003-of-00003.safetensors:   1%|    | 41.9M/4.55G [00:04<07:59, 9.40MB/s]
# model-00001-of-00003.safetensors:   3%|▏    | 126M/4.95G [00:04<03:26, 23.4MB/s]
#
# model-00002-of-00003.safetensors:   3%|▏    | 168M/5.00G [00:04<01:57, 41.0MB/s]
#
# model-00002-of-00003.safetensors:   4%|▏    | 178M/5.00G [00:05<02:08, 37.5MB/s]
# model-00001-of-00003.safetensors:   3%|▏    | 136M/4.95G [00:05<03:33, 22.6MB/s]
#
# model-00002-of-00003.safetensors:   4%|▏    | 189M/5.00G [00:05<02:06, 38.2MB/s]
#
# model-00002-of-00003.safetensors:   4%|▏    | 199M/5.00G [00:05<02:10, 36.7MB/s]
# model-00001-of-00003.safetensors:   3%|▏    | 147M/4.95G [00:05<03:36, 22.2MB/s]
#
#
# model-00003-of-00003.safetensors:   1%|    | 52.4M/4.55G [00:05<08:01, 9.34MB/s]
#
# model-00002-of-00003.safetensors:   4%|▏    | 210M/5.00G [00:05<02:09, 36.9MB/s]
#
# model-00002-of-00003.safetensors:   4%|▏    | 220M/5.00G [00:06<02:13, 35.7MB/s]
# model-00001-of-00003.safetensors:   3%|▏    | 157M/4.95G [00:06<03:50, 20.8MB/s]
#
#
#
# consolidated.safetensors:   0%|          | 21.0M/14.5G [00:06<1:10:25, 3.43MB/s]
#
# model-00002-of-00003.safetensors:   5%|▏    | 231M/5.00G [00:06<02:08, 37.2MB/s]
#
# model-00002-of-00003.safetensors:   5%|▏    | 241M/5.00G [00:06<02:01, 39.3MB/s]
# model-00001-of-00003.safetensors:   3%|▏    | 168M/4.95G [00:06<03:58, 20.0MB/s]
#
# model-00002-of-00003.safetensors:   5%|▎    | 252M/5.00G [00:07<02:14, 35.3MB/s]
#
#
# model-00003-of-00003.safetensors:   1%|    | 62.9M/4.55G [00:07<08:53, 8.40MB/s]
#
# model-00002-of-00003.safetensors:   5%|▎    | 262M/5.00G [00:07<02:14, 35.2MB/s]
# model-00001-of-00003.safetensors:   4%|▏    | 178M/4.95G [00:07<04:05, 19.4MB/s]
#
# model-00002-of-00003.safetensors:   5%|▎    | 273M/5.00G [00:07<02:08, 36.7MB/s]
#
# model-00002-of-00003.safetensors:   6%|▎    | 283M/5.00G [00:07<02:00, 39.2MB/s]
# model-00001-of-00003.safetensors:   4%|▏    | 189M/4.95G [00:08<03:57, 20.1MB/s]
#
# model-00002-of-00003.safetensors:   6%|▎    | 294M/5.00G [00:08<01:54, 41.1MB/s]
#
# model-00002-of-00003.safetensors:   6%|▎    | 304M/5.00G [00:08<01:51, 42.1MB/s]
#
#
# model-00003-of-00003.safetensors:   2%|    | 73.4M/4.55G [00:08<08:48, 8.47MB/s]
# model-00001-of-00003.safetensors:   4%|▏    | 199M/4.95G [00:08<04:01, 19.6MB/s]
#
# model-00002-of-00003.safetensors:   6%|▎    | 315M/5.00G [00:08<01:52, 41.8MB/s]
#
# model-00002-of-00003.safetensors:   7%|▎    | 325M/5.00G [00:08<01:53, 41.3MB/s]
#
#
#
# consolidated.safetensors:   0%|          | 31.5M/14.5G [00:08<1:05:00, 3.71MB/s]
#
# model-00002-of-00003.safetensors:   7%|▎    | 336M/5.00G [00:09<01:57, 39.8MB/s]
# model-00001-of-00003.safetensors:   4%|▏    | 210M/4.95G [00:09<04:30, 17.5MB/s]
#
# model-00002-of-00003.safetensors:   7%|▎    | 346M/5.00G [00:09<01:55, 40.2MB/s]
#
# model-00002-of-00003.safetensors:   7%|▎    | 357M/5.00G [00:09<01:50, 41.9MB/s]
#
#
# model-00003-of-00003.safetensors:   2%|    | 83.9M/4.55G [00:09<08:41, 8.57MB/s]
#
# model-00002-of-00003.safetensors:   7%|▎    | 367M/5.00G [00:09<01:46, 43.6MB/s]
# model-00001-of-00003.safetensors:   4%|▏    | 220M/4.95G [00:10<04:38, 17.0MB/s]
#
# model-00002-of-00003.safetensors:   8%|▍    | 377M/5.00G [00:10<01:45, 43.8MB/s]
#
# model-00002-of-00003.safetensors:   8%|▍    | 388M/5.00G [00:10<01:40, 46.0MB/s]
#
# model-00002-of-00003.safetensors:   8%|▍    | 398M/5.00G [00:10<01:38, 46.7MB/s]
#
# model-00002-of-00003.safetensors:   8%|▍    | 409M/5.00G [00:10<01:41, 45.1MB/s]
#
#
#
# consolidated.safetensors:   0%|            | 41.9M/14.5G [00:10<56:22, 4.27MB/s]
# model-00001-of-00003.safetensors:   5%|▏    | 231M/4.95G [00:10<05:23, 14.6MB/s]
#
# model-00002-of-00003.safetensors:   8%|▍    | 419M/5.00G [00:11<01:59, 38.2MB/s]
#
#
# model-00003-of-00003.safetensors:   2%|    | 94.4M/4.55G [00:11<09:13, 8.04MB/s]
#
# model-00002-of-00003.safetensors:   9%|▍    | 430M/5.00G [00:11<01:55, 39.6MB/s]
# model-00001-of-00003.safetensors:   5%|▏    | 241M/4.95G [00:11<05:15, 14.9MB/s]
#
# model-00002-of-00003.safetensors:   9%|▍    | 440M/5.00G [00:11<02:20, 32.6MB/s]
#
# model-00002-of-00003.safetensors:   9%|▍    | 451M/5.00G [00:12<02:27, 30.9MB/s]
# model-00001-of-00003.safetensors:   5%|▎    | 252M/4.95G [00:12<05:27, 14.4MB/s]
#
#
# model-00003-of-00003.safetensors:   2%|     | 105M/4.55G [00:12<09:10, 8.07MB/s]
#
# model-00002-of-00003.safetensors:   9%|▍    | 461M/5.00G [00:12<02:23, 31.6MB/s]
#
#
#
# consolidated.safetensors:   0%|            | 52.4M/14.5G [00:12<51:18, 4.69MB/s]
#
# model-00002-of-00003.safetensors:   9%|▍    | 472M/5.00G [00:12<02:33, 29.5MB/s]
# model-00001-of-00003.safetensors:   5%|▎    | 262M/4.95G [00:13<05:28, 14.2MB/s]
#
#
# model-00003-of-00003.safetensors:   3%|▏    | 115M/4.55G [00:13<08:09, 9.06MB/s]
#
# model-00002-of-00003.safetensors:  10%|▍    | 482M/5.00G [00:13<02:30, 30.0MB/s]
#
# model-00002-of-00003.safetensors:  10%|▍    | 493M/5.00G [00:13<02:23, 31.4MB/s]
# model-00001-of-00003.safetensors:   6%|▎    | 273M/4.95G [00:13<04:56, 15.8MB/s]
#
# model-00002-of-00003.safetensors:  10%|▌    | 503M/5.00G [00:13<02:27, 30.6MB/s]
#
#
# model-00003-of-00003.safetensors:   3%|▏    | 126M/4.55G [00:13<07:06, 10.4MB/s]
# model-00001-of-00003.safetensors:   6%|▎    | 283M/4.95G [00:14<04:41, 16.6MB/s]
#
#
#
# consolidated.safetensors:   0%|            | 62.9M/14.5G [00:14<45:10, 5.33MB/s]
#
# model-00002-of-00003.safetensors:  10%|▌    | 514M/5.00G [00:14<02:17, 32.7MB/s]
#
#
# model-00003-of-00003.safetensors:   3%|▏    | 136M/4.55G [00:14<06:30, 11.3MB/s]
#
# model-00002-of-00003.safetensors:  10%|▌    | 524M/5.00G [00:14<02:41, 27.7MB/s]
# model-00001-of-00003.safetensors:   6%|▎    | 294M/4.95G [00:14<04:36, 16.8MB/s]
#
# model-00002-of-00003.safetensors:  11%|▌    | 535M/5.00G [00:15<02:28, 30.0MB/s]
# model-00001-of-00003.safetensors:   6%|▎    | 304M/4.95G [00:15<04:28, 17.3MB/s]
#
#
# model-00003-of-00003.safetensors:   3%|▏    | 147M/4.55G [00:15<06:01, 12.2MB/s]
#
# model-00002-of-00003.safetensors:  11%|▌    | 545M/5.00G [00:15<02:45, 26.9MB/s]
# model-00001-of-00003.safetensors:   6%|▎    | 315M/4.95G [00:15<04:16, 18.0MB/s]
#
#
#
# consolidated.safetensors:   1%|            | 73.4M/14.5G [00:15<43:52, 5.48MB/s]
#
# model-00002-of-00003.safetensors:  11%|▌    | 556M/5.00G [00:16<03:03, 24.3MB/s]
#
#
# model-00003-of-00003.safetensors:   3%|▏    | 157M/4.55G [00:16<05:54, 12.4MB/s]
# model-00001-of-00003.safetensors:   7%|▎    | 325M/4.95G [00:16<04:09, 18.5MB/s]
#
# model-00002-of-00003.safetensors:  11%|▌    | 566M/5.00G [00:16<03:05, 23.9MB/s]
# model-00001-of-00003.safetensors:   7%|▎    | 336M/4.95G [00:17<04:30, 17.0MB/s]
#
# model-00002-of-00003.safetensors:  12%|▌    | 577M/5.00G [00:17<03:28, 21.2MB/s]
#
#
# model-00003-of-00003.safetensors:   4%|▏    | 168M/4.55G [00:17<06:01, 12.1MB/s]
#
#
#
# consolidated.safetensors:   1%|            | 83.9M/14.5G [00:17<38:23, 6.26MB/s]
# model-00001-of-00003.safetensors:   7%|▎    | 346M/4.95G [00:17<04:02, 19.0MB/s]
#
# model-00002-of-00003.safetensors:  12%|▌    | 587M/5.00G [00:17<03:21, 21.9MB/s]
# model-00001-of-00003.safetensors:   7%|▎    | 357M/4.95G [00:18<04:04, 18.8MB/s]
#
#
# model-00003-of-00003.safetensors:   4%|▏    | 178M/4.55G [00:18<06:12, 11.7MB/s]
#
# model-00002-of-00003.safetensors:  12%|▌    | 598M/5.00G [00:18<04:14, 17.3MB/s]
#
#
#
# consolidated.safetensors:   1%|            | 94.4M/14.5G [00:18<37:13, 6.45MB/s]
# model-00001-of-00003.safetensors:   7%|▎    | 367M/4.95G [00:18<04:18, 17.7MB/s]
# model-00001-of-00003.safetensors:   8%|▍    | 377M/4.95G [00:19<04:15, 17.9MB/s]
#
#
# model-00003-of-00003.safetensors:   4%|▏    | 189M/4.55G [00:19<07:22, 9.85MB/s]
#
# model-00002-of-00003.safetensors:  12%|▌    | 608M/5.00G [00:19<05:18, 13.8MB/s]
# model-00001-of-00003.safetensors:   8%|▍    | 388M/4.95G [00:19<04:01, 18.9MB/s]
#
#
#
# consolidated.safetensors:   1%|             | 105M/14.5G [00:19<35:36, 6.74MB/s]
# model-00001-of-00003.safetensors:   8%|▍    | 398M/4.95G [00:20<03:48, 19.9MB/s]
# model-00001-of-00003.safetensors:   8%|▍    | 409M/4.95G [00:20<03:23, 22.3MB/s]
#
#
# model-00003-of-00003.safetensors:   4%|▏    | 199M/4.55G [00:20<07:36, 9.52MB/s]
#
# model-00002-of-00003.safetensors:  12%|▌    | 619M/5.00G [00:20<06:09, 11.9MB/s]
#
#
#
# consolidated.safetensors:   1%|             | 115M/14.5G [00:20<29:58, 7.99MB/s]
# model-00001-of-00003.safetensors:   8%|▍    | 419M/4.95G [00:21<03:08, 24.1MB/s]
# model-00001-of-00003.safetensors:   9%|▍    | 430M/4.95G [00:21<03:00, 25.0MB/s]
#
#
#
# consolidated.safetensors:   1%|             | 126M/14.5G [00:21<25:40, 9.33MB/s]
#
# model-00002-of-00003.safetensors:  13%|▋    | 629M/5.00G [00:21<05:56, 12.3MB/s]
# model-00001-of-00003.safetensors:   9%|▍    | 440M/4.95G [00:21<02:49, 26.7MB/s]
#
#
# model-00003-of-00003.safetensors:   5%|▏    | 210M/4.55G [00:21<07:28, 9.68MB/s]
# model-00001-of-00003.safetensors:   9%|▍    | 451M/4.95G [00:22<02:52, 26.0MB/s]
#
# model-00002-of-00003.safetensors:  13%|▋    | 640M/5.00G [00:22<05:42, 12.7MB/s]
#
#
#
# consolidated.safetensors:   1%|             | 136M/14.5G [00:22<23:16, 10.3MB/s]
# model-00001-of-00003.safetensors:   9%|▍    | 461M/4.95G [00:22<02:47, 26.9MB/s]
# model-00001-of-00003.safetensors:  10%|▍    | 472M/4.95G [00:22<02:34, 29.0MB/s]
#
# model-00002-of-00003.safetensors:  13%|▋    | 650M/5.00G [00:22<05:03, 14.4MB/s]
#
#
# model-00003-of-00003.safetensors:   5%|▏    | 220M/4.55G [00:22<07:43, 9.34MB/s]
#
#
#
# consolidated.safetensors:   1%|▏            | 147M/14.5G [00:22<21:11, 11.3MB/s]
# model-00001-of-00003.safetensors:  10%|▍    | 482M/4.95G [00:23<02:40, 27.9MB/s]
#
# model-00002-of-00003.safetensors:  13%|▋    | 661M/5.00G [00:23<04:55, 14.7MB/s]
# model-00001-of-00003.safetensors:  10%|▍    | 493M/4.95G [00:23<02:36, 28.4MB/s]
# model-00001-of-00003.safetensors:  10%|▌    | 503M/4.95G [00:23<02:39, 27.8MB/s]
#
#
#
# consolidated.safetensors:   1%|▏            | 157M/14.5G [00:23<22:11, 10.8MB/s]
#
# model-00002-of-00003.safetensors:  13%|▋    | 671M/5.00G [00:24<05:18, 13.6MB/s]
#
#
# model-00003-of-00003.safetensors:   5%|▎    | 231M/4.55G [00:24<08:22, 8.60MB/s]
# model-00001-of-00003.safetensors:  10%|▌    | 514M/4.95G [00:24<03:15, 22.6MB/s]
# model-00001-of-00003.safetensors:  11%|▌    | 524M/4.95G [00:25<03:25, 21.5MB/s]
#
# model-00002-of-00003.safetensors:  14%|▋    | 682M/5.00G [00:25<05:40, 12.7MB/s]
#
#
#
# consolidated.safetensors:   1%|▏            | 168M/14.5G [00:25<24:07, 9.90MB/s]
# model-00001-of-00003.safetensors:  11%|▌    | 535M/4.95G [00:25<03:16, 22.5MB/s]
# model-00001-of-00003.safetensors:  11%|▌    | 545M/4.95G [00:26<03:06, 23.6MB/s]
#
#
# model-00003-of-00003.safetensors:   5%|▎    | 241M/4.55G [00:26<09:15, 7.75MB/s]
#
# model-00002-of-00003.safetensors:  14%|▋    | 692M/5.00G [00:26<06:00, 11.9MB/s]
# model-00001-of-00003.safetensors:  11%|▌    | 556M/4.95G [00:26<03:04, 23.8MB/s]
#
#
#
# consolidated.safetensors:   1%|▏            | 178M/14.5G [00:26<24:39, 9.68MB/s]
# model-00001-of-00003.safetensors:  11%|▌    | 566M/4.95G [00:26<02:50, 25.7MB/s]
#
# model-00002-of-00003.safetensors:  14%|▋    | 703M/5.00G [00:27<05:40, 12.6MB/s]
# model-00001-of-00003.safetensors:  12%|▌    | 577M/4.95G [00:27<02:44, 26.5MB/s]
#
#
# model-00003-of-00003.safetensors:   6%|▎    | 252M/4.55G [00:27<08:34, 8.35MB/s]
#
#
#
# consolidated.safetensors:   1%|▏            | 189M/14.5G [00:27<22:47, 10.5MB/s]
# model-00001-of-00003.safetensors:  12%|▌    | 587M/4.95G [00:27<02:43, 26.6MB/s]
#
# model-00002-of-00003.safetensors:  14%|▋    | 713M/5.00G [00:27<05:22, 13.3MB/s]
# model-00001-of-00003.safetensors:  12%|▌    | 598M/4.95G [00:27<02:51, 25.4MB/s]
#
#
# model-00003-of-00003.safetensors:   6%|▎    | 262M/4.55G [00:28<08:07, 8.79MB/s]
#
#
#
# consolidated.safetensors:   1%|▏            | 199M/14.5G [00:28<21:55, 10.9MB/s]
# model-00001-of-00003.safetensors:  12%|▌    | 608M/4.95G [00:28<02:52, 25.2MB/s]
#
# model-00002-of-00003.safetensors:  14%|▋    | 724M/5.00G [00:28<05:18, 13.4MB/s]
# model-00001-of-00003.safetensors:  12%|▌    | 619M/4.95G [00:28<02:49, 25.5MB/s]
#
#
#
# consolidated.safetensors:   1%|▏            | 210M/14.5G [00:28<20:07, 11.8MB/s]
# model-00001-of-00003.safetensors:  13%|▋    | 629M/4.95G [00:29<02:45, 26.1MB/s]
#
#
# model-00003-of-00003.safetensors:   6%|▎    | 273M/4.55G [00:29<07:34, 9.41MB/s]
#
# model-00002-of-00003.safetensors:  15%|▋    | 734M/5.00G [00:29<05:10, 13.7MB/s]
# model-00001-of-00003.safetensors:  13%|▋    | 640M/4.95G [00:29<02:38, 27.1MB/s]
#
#
#
# consolidated.safetensors:   2%|▏            | 220M/14.5G [00:29<19:46, 12.0MB/s]
# model-00001-of-00003.safetensors:  13%|▋    | 650M/4.95G [00:29<02:44, 26.2MB/s]
#
#
# model-00003-of-00003.safetensors:   6%|▎    | 283M/4.55G [00:29<06:53, 10.3MB/s]
#
# model-00002-of-00003.safetensors:  15%|▋    | 744M/5.00G [00:30<05:12, 13.6MB/s]
#
#
#
# consolidated.safetensors:   2%|▏            | 231M/14.5G [00:30<20:13, 11.8MB/s]
# model-00001-of-00003.safetensors:  14%|▋    | 671M/4.95G [00:30<02:52, 24.8MB/s]
#
# model-00002-of-00003.safetensors:  15%|▊    | 755M/5.00G [00:31<05:39, 12.5MB/s]
#
#
# model-00003-of-00003.safetensors:   6%|▎    | 294M/4.55G [00:31<07:17, 9.72MB/s]
# model-00001-of-00003.safetensors:  14%|▋    | 682M/4.95G [00:31<02:59, 23.8MB/s]
#
#
#
# consolidated.safetensors:   2%|▏            | 241M/14.5G [00:31<20:12, 11.8MB/s]
# model-00001-of-00003.safetensors:  14%|▋    | 692M/4.95G [00:31<02:54, 24.4MB/s]
#
# model-00002-of-00003.safetensors:  15%|▊    | 765M/5.00G [00:31<05:35, 12.6MB/s]
# model-00001-of-00003.safetensors:  14%|▋    | 703M/4.95G [00:32<02:43, 25.9MB/s]
#
#
# model-00003-of-00003.safetensors:   7%|▎    | 304M/4.55G [00:32<07:19, 9.66MB/s]
#
#
#
# consolidated.safetensors:   2%|▏            | 252M/14.5G [00:32<19:11, 12.4MB/s]
# model-00001-of-00003.safetensors:  14%|▋    | 713M/4.95G [00:32<02:34, 27.5MB/s]
#
# model-00002-of-00003.safetensors:  16%|▊    | 776M/5.00G [00:32<05:15, 13.4MB/s]
# model-00001-of-00003.safetensors:  15%|▋    | 724M/4.95G [00:32<02:39, 26.5MB/s]
#
#
#
# model-00001-of-00003.safetensors:  15%|▋    | 734M/4.95G [00:33<02:45, 25.5MB/s]
#
# model-00002-of-00003.safetensors:  16%|▊    | 786M/5.00G [00:33<05:09, 13.6MB/s]
#
#
# model-00003-of-00003.safetensors:   7%|▎    | 315M/4.55G [00:33<07:22, 9.57MB/s]
# model-00001-of-00003.safetensors:  15%|▊    | 744M/4.95G [00:33<02:47, 25.1MB/s]
#
# model-00002-of-00003.safetensors:  16%|▊    | 797M/5.00G [00:33<04:56, 14.2MB/s]
# model-00001-of-00003.safetensors:  15%|▊    | 755M/4.95G [00:34<02:38, 26.5MB/s]
#
#
#
# consolidated.safetensors:   2%|▏            | 273M/14.5G [00:33<19:34, 12.1MB/s]
#
#
# model-00003-of-00003.safetensors:   7%|▎    | 325M/4.55G [00:34<07:06, 9.90MB/s]
# model-00001-of-00003.safetensors:  15%|▊    | 765M/4.95G [00:34<02:31, 27.6MB/s]
#
# model-00002-of-00003.safetensors:  16%|▊    | 807M/5.00G [00:34<04:44, 14.7MB/s]
# model-00001-of-00003.safetensors:  16%|▊    | 776M/4.95G [00:34<02:39, 26.1MB/s]
#
# model-00002-of-00003.safetensors:  16%|▊    | 818M/5.00G [00:34<04:03, 17.2MB/s]
# model-00001-of-00003.safetensors:  16%|▊    | 786M/4.95G [00:35<02:32, 27.3MB/s]
#
#
#
# consolidated.safetensors:   2%|▎            | 283M/14.5G [00:35<21:17, 11.1MB/s]
#
# model-00002-of-00003.safetensors:  17%|▊    | 828M/5.00G [00:35<03:49, 18.2MB/s]
# model-00001-of-00003.safetensors:  16%|▊    | 797M/4.95G [00:35<02:26, 28.3MB/s]
#
#
# model-00003-of-00003.safetensors:   7%|▎    | 336M/4.55G [00:35<07:31, 9.33MB/s]
# model-00001-of-00003.safetensors:  16%|▊    | 807M/4.95G [00:35<02:30, 27.5MB/s]
#
# model-00002-of-00003.safetensors:  17%|▊    | 839M/5.00G [00:35<03:34, 19.4MB/s]
#
#
#
# consolidated.safetensors:   2%|▎            | 294M/14.5G [00:35<20:21, 11.6MB/s]
# model-00001-of-00003.safetensors:  17%|▊    | 818M/4.95G [00:36<02:40, 25.8MB/s]
#
# model-00002-of-00003.safetensors:  17%|▊    | 849M/5.00G [00:36<03:27, 20.0MB/s]
#
#
# model-00003-of-00003.safetensors:   8%|▍    | 346M/4.55G [00:36<07:24, 9.45MB/s]
# model-00001-of-00003.safetensors:  17%|▊    | 828M/4.95G [00:36<02:39, 25.9MB/s]
#
# model-00002-of-00003.safetensors:  17%|▊    | 860M/5.00G [00:36<03:10, 21.7MB/s]
#
#
#
# consolidated.safetensors:   2%|▎            | 304M/14.5G [00:36<19:32, 12.1MB/s]
# model-00001-of-00003.safetensors:  17%|▊    | 839M/4.95G [00:37<02:43, 25.2MB/s]
#
# model-00002-of-00003.safetensors:  17%|▊    | 870M/5.00G [00:37<03:04, 22.4MB/s]
#
# model-00002-of-00003.safetensors:  18%|▉    | 881M/5.00G [00:37<02:47, 24.6MB/s]
#
#
#
# consolidated.safetensors:   2%|▎            | 315M/14.5G [00:37<18:52, 12.5MB/s]
# model-00001-of-00003.safetensors:  17%|▊    | 849M/4.95G [00:37<02:39, 25.7MB/s]
#
#
# model-00003-of-00003.safetensors:   8%|▍    | 357M/4.55G [00:37<07:12, 9.68MB/s]
#
# model-00002-of-00003.safetensors:  18%|▉    | 891M/5.00G [00:37<02:40, 25.6MB/s]
# model-00001-of-00003.safetensors:  17%|▊    | 860M/4.95G [00:38<02:39, 25.6MB/s]
#
#
#
# consolidated.safetensors:   2%|▎            | 325M/14.5G [00:38<18:00, 13.1MB/s]
#
# model-00002-of-00003.safetensors:  18%|▉    | 902M/5.00G [00:38<02:44, 24.9MB/s]
# model-00001-of-00003.safetensors:  18%|▉    | 870M/4.95G [00:38<02:41, 25.3MB/s]
#
#
# model-00003-of-00003.safetensors:   8%|▍    | 367M/4.55G [00:38<06:31, 10.7MB/s]
#
# model-00002-of-00003.safetensors:  18%|▉    | 912M/5.00G [00:38<02:46, 24.5MB/s]
# model-00001-of-00003.safetensors:  18%|▉    | 881M/4.95G [00:38<02:44, 24.7MB/s]
#
#
#
# consolidated.safetensors:   2%|▎            | 336M/14.5G [00:38<17:28, 13.5MB/s]
#
# model-00002-of-00003.safetensors:  18%|▉    | 923M/5.00G [00:39<03:00, 22.6MB/s]
#
#
# model-00003-of-00003.safetensors:   8%|▍    | 377M/4.55G [00:39<06:24, 10.9MB/s]
# model-00001-of-00003.safetensors:  18%|▉    | 891M/4.95G [00:39<03:01, 22.4MB/s]
#
#
#
# consolidated.safetensors:   2%|▎            | 346M/14.5G [00:39<17:38, 13.4MB/s]
#
# model-00002-of-00003.safetensors:  19%|▉    | 933M/5.00G [00:39<03:19, 20.4MB/s]
# model-00001-of-00003.safetensors:  18%|▉    | 902M/4.95G [00:40<03:36, 18.7MB/s]
#
#
# model-00003-of-00003.safetensors:   9%|▍    | 388M/4.55G [00:40<06:28, 10.7MB/s]
#
# model-00002-of-00003.safetensors:  19%|▉    | 944M/5.00G [00:40<03:31, 19.2MB/s]
#
#
#
# consolidated.safetensors:   2%|▎            | 357M/14.5G [00:40<18:36, 12.7MB/s]
# model-00001-of-00003.safetensors:  18%|▉    | 912M/4.95G [00:40<03:55, 17.2MB/s]
#
# model-00002-of-00003.safetensors:  19%|▉    | 954M/5.00G [00:41<03:48, 17.7MB/s]
#
#
# model-00003-of-00003.safetensors:   9%|▍    | 398M/4.55G [00:41<06:20, 10.9MB/s]
#
#
#
# consolidated.safetensors:   3%|▎            | 367M/14.5G [00:41<20:38, 11.4MB/s]
#
# model-00002-of-00003.safetensors:  19%|▉    | 965M/5.00G [00:42<04:28, 15.0MB/s]
#
#
# model-00003-of-00003.safetensors:   9%|▍    | 409M/4.55G [00:42<06:23, 10.8MB/s]
#
#
#
# consolidated.safetensors:   3%|▎            | 377M/14.5G [00:42<19:40, 12.0MB/s]
# model-00001-of-00003.safetensors:  19%|▉    | 923M/4.95G [00:42<06:22, 10.5MB/s]
#
# model-00002-of-00003.safetensors:  20%|▉    | 975M/5.00G [00:43<04:42, 14.3MB/s]
#
#
# model-00003-of-00003.safetensors:   9%|▍    | 419M/4.55G [00:43<06:04, 11.3MB/s]
#
#
#
# consolidated.safetensors:   3%|▎            | 388M/14.5G [00:43<19:17, 12.2MB/s]
#
#
# model-00003-of-00003.safetensors:   9%|▍    | 430M/4.55G [00:43<05:31, 12.4MB/s]
#
#
#
# consolidated.safetensors:   3%|▎            | 398M/14.5G [00:43<17:02, 13.8MB/s]
#
# model-00002-of-00003.safetensors:  20%|▉    | 986M/5.00G [00:44<05:16, 12.7MB/s]
# model-00001-of-00003.safetensors:  19%|▉    | 933M/4.95G [00:44<06:55, 9.66MB/s]
#
#
# model-00003-of-00003.safetensors:  10%|▍    | 440M/4.55G [00:44<04:49, 14.2MB/s]
#
#
#
# consolidated.safetensors:   3%|▎            | 409M/14.5G [00:44<15:04, 15.6MB/s]
#
#
# model-00003-of-00003.safetensors:  10%|▍    | 451M/4.55G [00:44<04:32, 15.1MB/s]
#
# model-00002-of-00003.safetensors:  20%|▉    | 996M/5.00G [00:44<05:12, 12.8MB/s]
#
#
#
# consolidated.safetensors:   3%|▍            | 419M/14.5G [00:44<15:02, 15.6MB/s]
# model-00001-of-00003.safetensors:  19%|▉    | 944M/4.95G [00:45<07:03, 9.47MB/s]
#
#
# model-00003-of-00003.safetensors:  10%|▌    | 461M/4.55G [00:45<04:10, 16.3MB/s]
#
# model-00002-of-00003.safetensors:  20%|▊   | 1.01G/5.00G [00:45<05:07, 13.0MB/s]
#
#
#
# consolidated.safetensors:   3%|▍            | 430M/14.5G [00:45<14:33, 16.1MB/s]
#
#
# model-00003-of-00003.safetensors:  10%|▌    | 472M/4.55G [00:45<03:45, 18.1MB/s]
#
#
# model-00003-of-00003.safetensors:  11%|▌    | 482M/4.55G [00:46<03:24, 19.9MB/s]
#
#
#
# consolidated.safetensors:   3%|▍            | 440M/14.5G [00:46<13:31, 17.3MB/s]
#
# model-00002-of-00003.safetensors:  20%|▊   | 1.02G/5.00G [00:46<04:37, 14.4MB/s]
# model-00001-of-00003.safetensors:  19%|▉    | 954M/4.95G [00:46<06:50, 9.72MB/s]
#
#
# model-00003-of-00003.safetensors:  11%|▌    | 493M/4.55G [00:46<03:06, 21.7MB/s]
#
#
#
# consolidated.safetensors:   3%|▍            | 451M/14.5G [00:46<12:25, 18.8MB/s]
#
# model-00002-of-00003.safetensors:  21%|▊   | 1.03G/5.00G [00:46<04:08, 16.0MB/s]
#
#
# model-00003-of-00003.safetensors:  11%|▌    | 503M/4.55G [00:47<03:07, 21.5MB/s]
#
#
#
# consolidated.safetensors:   3%|▍            | 461M/14.5G [00:47<12:23, 18.9MB/s]
#
# model-00002-of-00003.safetensors:  21%|▊   | 1.04G/5.00G [00:47<03:55, 16.8MB/s]
# model-00001-of-00003.safetensors:  19%|▉    | 965M/4.95G [00:47<06:52, 9.67MB/s]
#
#
# model-00003-of-00003.safetensors:  11%|▌    | 514M/4.55G [00:47<02:59, 22.4MB/s]
#
# model-00002-of-00003.safetensors:  21%|▊   | 1.05G/5.00G [00:47<03:44, 17.6MB/s]
#
#
#
# consolidated.safetensors:   3%|▍            | 472M/14.5G [00:47<12:31, 18.7MB/s]
#
#
# model-00003-of-00003.safetensors:  12%|▌    | 524M/4.55G [00:47<03:02, 22.0MB/s]
#
# model-00002-of-00003.safetensors:  21%|▊   | 1.06G/5.00G [00:48<03:42, 17.7MB/s]
# model-00001-of-00003.safetensors:  20%|▉    | 975M/4.95G [00:48<06:45, 9.80MB/s]
#
#
#
# consolidated.safetensors:   3%|▍            | 482M/14.5G [00:48<14:14, 16.4MB/s]
#
#
# model-00003-of-00003.safetensors:  12%|▌    | 535M/4.55G [00:48<03:21, 19.9MB/s]
#
# model-00002-of-00003.safetensors:  21%|▊   | 1.07G/5.00G [00:48<03:22, 19.4MB/s]
#
#
# model-00003-of-00003.safetensors:  12%|▌    | 545M/4.55G [00:49<03:23, 19.7MB/s]
#
# model-00002-of-00003.safetensors:  22%|▊   | 1.08G/5.00G [00:49<03:09, 20.7MB/s]
#
#
#
# consolidated.safetensors:   3%|▍            | 493M/14.5G [00:49<14:33, 16.0MB/s]
# model-00001-of-00003.safetensors:  20%|▉    | 986M/4.95G [00:49<06:24, 10.3MB/s]
#
# model-00002-of-00003.safetensors:  22%|▊   | 1.09G/5.00G [00:49<03:06, 21.0MB/s]
#
#
# model-00003-of-00003.safetensors:  12%|▌    | 556M/4.55G [00:49<03:33, 18.7MB/s]
#
# model-00002-of-00003.safetensors:  22%|▉   | 1.10G/5.00G [00:50<02:45, 23.5MB/s]
#
#
#
# consolidated.safetensors:   3%|▍            | 503M/14.5G [00:49<15:24, 15.1MB/s]
# model-00001-of-00003.safetensors:  20%|█    | 996M/4.95G [00:50<06:08, 10.7MB/s]
#
#
# model-00003-of-00003.safetensors:  12%|▌    | 566M/4.55G [00:50<03:43, 17.8MB/s]
#
# model-00002-of-00003.safetensors:  22%|▉   | 1.11G/5.00G [00:50<02:48, 23.1MB/s]
#
# model-00002-of-00003.safetensors:  22%|▉   | 1.12G/5.00G [00:50<02:37, 24.6MB/s]
#
#
#
# consolidated.safetensors:   4%|▍            | 514M/14.5G [00:50<16:21, 14.2MB/s]
#
#
# model-00003-of-00003.safetensors:  13%|▋    | 577M/4.55G [00:50<03:33, 18.6MB/s]
# model-00001-of-00003.safetensors:  20%|▊   | 1.01G/4.95G [00:51<06:07, 10.7MB/s]
#
# model-00002-of-00003.safetensors:  23%|▉   | 1.13G/5.00G [00:51<02:36, 24.7MB/s]
#
#
# model-00003-of-00003.safetensors:  13%|▋    | 587M/4.55G [00:51<03:26, 19.1MB/s]
#
# model-00002-of-00003.safetensors:  23%|▉   | 1.14G/5.00G [00:51<02:30, 25.6MB/s]
#
#
#
# consolidated.safetensors:   4%|▍            | 524M/14.5G [00:51<16:58, 13.7MB/s]
#
#
# model-00003-of-00003.safetensors:  13%|▋    | 598M/4.55G [00:52<03:26, 19.2MB/s]
#
# model-00002-of-00003.safetensors:  23%|▉   | 1.15G/5.00G [00:52<02:37, 24.5MB/s]
# model-00001-of-00003.safetensors:  21%|▊   | 1.02G/4.95G [00:52<06:16, 10.5MB/s]
#
# model-00002-of-00003.safetensors:  23%|▉   | 1.16G/5.00G [00:52<02:24, 26.5MB/s]
#
#
#
# consolidated.safetensors:   4%|▍            | 535M/14.5G [00:52<17:23, 13.4MB/s]
#
#
# model-00003-of-00003.safetensors:  13%|▋    | 608M/4.55G [00:52<03:28, 18.9MB/s]
#
# model-00002-of-00003.safetensors:  23%|▉   | 1.17G/5.00G [00:52<02:22, 26.9MB/s]
#
# model-00002-of-00003.safetensors:  24%|▉   | 1.18G/5.00G [00:53<02:29, 25.5MB/s]
#
#
# model-00003-of-00003.safetensors:  14%|▋    | 619M/4.55G [00:53<03:49, 17.1MB/s]
# model-00001-of-00003.safetensors:  21%|▊   | 1.03G/4.95G [00:53<06:42, 9.76MB/s]
#
# model-00002-of-00003.safetensors:  24%|▉   | 1.20G/5.00G [00:53<02:18, 27.4MB/s]
#
# model-00002-of-00003.safetensors:  24%|▉   | 1.21G/5.00G [00:53<02:00, 31.4MB/s]
#
#
#
# consolidated.safetensors:   4%|▍            | 545M/14.5G [00:53<21:11, 11.0MB/s]
#
# model-00002-of-00003.safetensors:  24%|▉   | 1.22G/5.00G [00:54<01:58, 32.0MB/s]
#
# model-00002-of-00003.safetensors:  25%|▉   | 1.23G/5.00G [00:54<01:55, 32.6MB/s]
#
#
# model-00003-of-00003.safetensors:  14%|▋    | 629M/4.55G [00:54<05:00, 13.0MB/s]
#
# model-00002-of-00003.safetensors:  25%|▉   | 1.24G/5.00G [00:54<01:48, 34.7MB/s]
#
# model-00002-of-00003.safetensors:  25%|▉   | 1.25G/5.00G [00:54<01:47, 35.0MB/s]
#
# model-00002-of-00003.safetensors:  25%|█   | 1.26G/5.00G [00:55<01:51, 33.5MB/s]
#
#
#
# consolidated.safetensors:   4%|▍            | 556M/14.5G [00:55<24:55, 9.32MB/s]
# model-00001-of-00003.safetensors:  21%|▊   | 1.04G/4.95G [00:55<08:26, 7.72MB/s]
#
# model-00002-of-00003.safetensors:  25%|█   | 1.27G/5.00G [00:55<01:54, 32.5MB/s]
#
#
# model-00003-of-00003.safetensors:  14%|▋    | 640M/4.55G [00:55<05:36, 11.6MB/s]
#
# model-00002-of-00003.safetensors:  26%|█   | 1.28G/5.00G [00:56<01:59, 31.0MB/s]
#
# model-00002-of-00003.safetensors:  26%|█   | 1.29G/5.00G [00:56<01:55, 32.2MB/s]
#
# model-00002-of-00003.safetensors:  26%|█   | 1.30G/5.00G [00:56<01:49, 33.9MB/s]
#
#
#
# consolidated.safetensors:   4%|▌            | 566M/14.5G [00:56<25:11, 9.22MB/s]
#
#
# model-00003-of-00003.safetensors:  14%|▋    | 650M/4.55G [00:56<05:33, 11.7MB/s]
# model-00001-of-00003.safetensors:  21%|▊   | 1.05G/4.95G [00:56<08:23, 7.74MB/s]
#
# model-00002-of-00003.safetensors:  26%|█   | 1.31G/5.00G [00:57<01:58, 31.2MB/s]
#
# model-00002-of-00003.safetensors:  26%|█   | 1.32G/5.00G [00:57<02:00, 30.6MB/s]
#
#
# model-00003-of-00003.safetensors:  15%|▋    | 661M/4.55G [00:57<05:24, 12.0MB/s]
#
# model-00002-of-00003.safetensors:  27%|█   | 1.33G/5.00G [00:57<02:00, 30.5MB/s]
#
#
#
# consolidated.safetensors:   4%|▌            | 577M/14.5G [00:57<25:31, 9.09MB/s]
# model-00001-of-00003.safetensors:  21%|▊   | 1.06G/4.95G [00:58<07:57, 8.14MB/s]
#
# model-00002-of-00003.safetensors:  27%|█   | 1.34G/5.00G [00:58<02:07, 28.8MB/s]
#
#
# model-00003-of-00003.safetensors:  15%|▋    | 671M/4.55G [00:58<05:08, 12.6MB/s]
#
# model-00002-of-00003.safetensors:  27%|█   | 1.35G/5.00G [00:58<02:10, 28.0MB/s]
#
#
# model-00003-of-00003.safetensors:  15%|▋    | 682M/4.55G [00:58<04:38, 13.9MB/s]
#
# model-00002-of-00003.safetensors:  27%|█   | 1.36G/5.00G [00:58<02:05, 29.0MB/s]
#
#
#
# consolidated.safetensors:   4%|▌            | 587M/14.5G [00:58<24:58, 9.28MB/s]
# model-00001-of-00003.safetensors:  22%|▊   | 1.07G/4.95G [00:59<07:33, 8.55MB/s]
#
# model-00002-of-00003.safetensors:  27%|█   | 1.37G/5.00G [00:59<02:10, 27.7MB/s]
#
#
# model-00003-of-00003.safetensors:  15%|▊    | 692M/4.55G [00:59<04:23, 14.6MB/s]
#
# model-00002-of-00003.safetensors:  28%|█   | 1.38G/5.00G [00:59<02:12, 27.4MB/s]
#
#
#
# consolidated.safetensors:   4%|▌            | 598M/14.5G [00:59<24:07, 9.60MB/s]
# model-00001-of-00003.safetensors:  22%|▊   | 1.08G/4.95G [01:00<07:02, 9.16MB/s]
#
#
# model-00003-of-00003.safetensors:  15%|▊    | 703M/4.55G [01:00<04:18, 14.9MB/s]
#
# model-00002-of-00003.safetensors:  28%|█   | 1.39G/5.00G [01:00<02:13, 27.0MB/s]
#
# model-00002-of-00003.safetensors:  28%|█   | 1.41G/5.00G [01:00<02:22, 25.2MB/s]
#
#
# model-00003-of-00003.safetensors:  16%|▊    | 713M/4.55G [01:00<04:25, 14.5MB/s]
#
# model-00002-of-00003.safetensors:  28%|█▏  | 1.42G/5.00G [01:00<02:25, 24.7MB/s]
# model-00001-of-00003.safetensors:  22%|▉   | 1.09G/4.95G [01:01<07:01, 9.15MB/s]
#
#
#
# consolidated.safetensors:   4%|▌            | 608M/14.5G [01:01<26:05, 8.87MB/s]
#
# model-00002-of-00003.safetensors:  29%|█▏  | 1.43G/5.00G [01:01<02:24, 24.7MB/s]
#
#
# model-00003-of-00003.safetensors:  16%|▊    | 724M/4.55G [01:01<04:13, 15.1MB/s]
#
# model-00002-of-00003.safetensors:  29%|█▏  | 1.44G/5.00G [01:01<02:20, 25.3MB/s]
# model-00001-of-00003.safetensors:  22%|▉   | 1.10G/4.95G [01:02<06:31, 9.84MB/s]
#
#
# model-00003-of-00003.safetensors:  16%|▊    | 734M/4.55G [01:02<03:59, 15.9MB/s]
#
# model-00002-of-00003.safetensors:  29%|█▏  | 1.45G/5.00G [01:02<02:29, 23.7MB/s]
#
#
# model-00003-of-00003.safetensors:  16%|▊    | 744M/4.55G [01:02<03:42, 17.1MB/s]
#
#
#
# consolidated.safetensors:   4%|▌            | 619M/14.5G [01:02<26:58, 8.58MB/s]
#
# model-00002-of-00003.safetensors:  29%|█▏  | 1.46G/5.00G [01:02<02:22, 24.8MB/s]
# model-00001-of-00003.safetensors:  22%|▉   | 1.11G/4.95G [01:03<06:14, 10.2MB/s]
#
#
# model-00003-of-00003.safetensors:  17%
B/s]
#
#
# model-00003-of-00003.safetensors:  21%|█    | 944M/4.55G [01:09<02:13, 26.9MB/s]
#
#
#
# consolidated.safetensors:   5%|▌            | 682M/14.5G [01:09<25:36, 8.99MB/s]
# model-00001-of-00003.safetensors:  24%|▉   | 1.18G/4.95G [01:09<04:56, 12.7MB/s]
#
# model-00002-of-00003.safetensors:  31%|█▎  | 1.57G/5.00G [01:09<03:23, 16.8MB/s]
#
#
# model-00003-of-00003.safetensors:  21%|█    | 954M/4.55G [01:09<02:18, 26.0MB/s]
#
#
# model-00003-of-00003.safetensors:  21%|█    | 965M/4.55G [01:10<02:18, 25.8MB/s]
# model-00001-of-00003.safetensors:  24%|▉   | 1.20G/4.95G [01:10<04:30, 13.9MB/s]
#
# model-00002-of-00003.safetensors:  32%|█▎  | 1.58G/5.00G [01:10<03:12, 17.8MB/s]
#
#
#
# consolidated.safetensors:   5%|▌            | 692M/14.5G [01:10<23:55, 9.62MB/s]
#
#
# model-00003-of-00003.safetensors:  21%|█    | 975M/4.55G [01:10<02:20, 25.4MB/s]
#
# model-00002-of-00003.safetensors:  32%|█▎  | 1.59G/5.00G [01:10<02:59, 18.9MB/s]
# model-00001-of-00003.safetensors:  24%|▉   | 1.21G/4.95G [01:10<04:11, 14.9MB/s]
#
#
# model-00003-of-00003.safetensors:  22%|█    | 986M/4.55G [01:10<02:20, 25.4MB/s]
#
# model-00002-of-00003.safetensors:  32%|█▎  | 1.60G/5.00G [01:11<02:51, 19.8MB/s]
#
#
#
# consolidated.safetensors:   5%|▋            | 703M/14.5G [01:10<22:10, 10.4MB/s]
# model-00001-of-00003.safetensors:  25%|▉   | 1.22G/4.95G [01:11<04:07, 15.1MB/s]
#
#
# model-00003-of-00003.safetensors:  22%|█    | 996M/4.55G [01:11<02:36, 22.7MB/s]
#
# model-00002-of-00003.safetensors:  32%|█▎  | 1.61G/5.00G [01:11<02:50, 19.9MB/s]
#
#
#
# consolidated.safetensors:   5%|▋            | 713M/14.5G [01:11<21:09, 10.9MB/s]
#
#
# model-00003-of-00003.safetensors:  22%|▉   | 1.01G/4.55G [01:11<02:41, 21.9MB/s]
# model-00001-of-00003.safetensors:  25%|▉   | 1.23G/4.95G [01:12<04:04, 15.2MB/s]
#
# model-00002-of-00003.safetensors:  33%|█▎  | 1.63G/5.00G [01:12<02:45, 20.4MB/s]
#
# model-00002-of-00003.safetensors:  33%|█▎  | 1.64G/5.00G [01:12<02:43, 20.5MB/s]
#
#
# model-00003-of-00003.safetensors:  22%|▉   | 1.02G/4.55G [01:12<02:55, 20.2MB/s]
# model-00001-of-00003.safetensors:  25%|▉   | 1.24G/4.95G [01:12<04:09, 14.9MB/s]
#
#
#
# consolidated.safetensors:   5%|▋            | 724M/14.5G [01:12<20:41, 11.1MB/s]
#
# model-00002-of-00003.safetensors:  33%|█▎  | 1.65G/5.00G [01:12<02:35, 21.6MB/s]
#
#
# model-00003-of-00003.safetensors:  23%|▉   | 1.03G/4.55G [01:13<03:07, 18.8MB/s]
# model-00001-of-00003.safetensors:  25%|█   | 1.25G/4.95G [01:13<03:54, 15.8MB/s]
#
# model-00002-of-00003.safetensors:  33%|█▎  | 1.66G/5.00G [01:13<02:30, 22.3MB/s]
#
#
# model-00003-of-00003.safetensors:  23%|▉   | 1.04G/4.55G [01:13<02:49, 20.6MB/s]
#
#
#
# consolidated.safetensors:   5%|▋            | 734M/14.5G [01:13<20:51, 11.0MB/s]
#
# model-00002-of-00003.safetensors:  33%|█▎  | 1.67G/5.00G [01:13<02:20, 23.8MB/s]
# model-00001-of-00003.safetensors:  25%|█   | 1.26G/4.95G [01:13<03:32, 17.4MB/s]
#
# model-00002-of-00003.safetensors:  34%|█▎  | 1.68G/5.00G [01:14<02:05, 26.5MB/s]
# model-00001-of-00003.safetensors:  26%|█   | 1.27G/4.95G [01:14<03:14, 19.0MB/s]
#
# model-00002-of-00003.safetensors:  34%|█▎  | 1.69G/5.00G [01:14<02:02, 27.0MB/s]
#
#
# model-00003-of-00003.safetensors:  23%|▉   | 1.05G/4.55G [01:14<03:47, 15.4MB/s]
# model-00001-of-00003.safetensors:  26%|█   | 1.28G/4.95G [01:14<03:14, 18.9MB/s]
#
# model-00002-of-00003.safetensors:  34%|█▎  | 1.70G/5.00G [01:14<02:04, 26.6MB/s]
#
#
#
# consolidated.safetensors:   5%|▋            | 744M/14.5G [01:15<25:34, 8.96MB/s]
#
# model-00002-of-00003.safetensors:  34%|█▎  | 1.71G/5.00G [01:15<02:25, 22.6MB/s]
# model-00001-of-00003.safetensors:  26%|█   | 1.29G/4.95G [01:15<03:37, 16.8MB/s]
#
#
# model-00003-of-00003.safetensors:  23%|▉   | 1.06G/4.55G [01:15<04:23, 13.2MB/s]
#
# model-00002-of-00003.safetensors:  34%|█▍  | 1.72G/5.00G [01:16<02:43, 20.1MB/s]
# model-00001-of-00003.safetensors:  26%|█   | 1.30G/4.95G [01:16<03:57, 15.4MB/s]
#
#
# model-00003-of-00003.safetensors:  24%|▉   | 1.07G/4.55G [01:16<04:30, 12.8MB/s]
#
#
#
# consolidated.safetensors:   5%|▋            | 755M/14.5G [01:16<26:01, 8.80MB/s]
#
# model-00002-of-00003.safetensors:  35%|█▍  | 1.73G/5.00G [01:16<03:03, 17.9MB/s]
# model-00001-of-00003.safetensors:  26%|█   | 1.31G/4.95G [01:17<03:58, 15.2MB/s]
#
#
# model-00003-of-00003.safetensors:  24%|▉   | 1.08G/4.55G [01:17<04:37, 12.5MB/s]
# model-00001-of-00003.safetensors:  27%|█   | 1.32G/4.95G [01:17<04:05, 14.8MB/s]
#
#
#
# consolidated.safetensors:   5%|▋            | 765M/14.5G [01:17<26:54, 8.51MB/s]
#
# model-00002-of-00003.safetensors:  35%|█▍  | 1.74G/5.00G [01:18<03:57, 13.7MB/s]
#
#
# model-00003-of-00003.safetensors:  24%|▉   | 1.09G/4.55G [01:18<04:29, 12.8MB/s]
# model-00001-of-00003.safetensors:  27%|█   | 1.33G/4.95G [01:18<04:01, 15.0MB/s]
#
#
# model-00003-of-00003.safetensors:  24%|▉   | 1.10G/4.55G [01:18<03:53, 14.8MB/s]
#
#
#
# consolidated.safetensors:   5%|▋            | 776M/14.5G [01:18<24:11, 9.45MB/s]
#
# model-00002-of-00003.safetensors:  35%|█▍  | 1.75G/5.00G [01:18<04:13, 12.8MB/s]
# model-00001-of-00003.safetensors:  27%|█   | 1.34G/4.95G [01:19<04:01, 14.9MB/s]
#
#
# model-00003-of-00003.safetensors:  24%|▉   | 1.11G/4.55G [01:19<03:39, 15.7MB/s]
#
#
#
# consolidated.safetensors:   5%|▋            | 786M/14.5G [01:19<22:52, 9.99MB/s]
#
# model-00002-of-00003.safetensors:  35%|█▍  | 1.76G/5.00G [01:19<04:17, 12.6MB/s]
#
#
# model-00003-of-00003.safetensors:  25%|▉   | 1.12G/4.55G [01:19<03:28, 16.4MB/s]
# ...
#
#
#
# consolidated.safetensors:  87%|██████████▍ | 12.6G/14.5G
B/s]
#
#
#
# consolidated.safetensors:  96%|███████████▌| 14.0G/14.5G [15:29<00:39, 13.2MB/s]
#
#
#
# consolidated.safetensors:  96%|███████████▌| 14.0G/14.5G [15:30<00:39, 13.0MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▌| 14.0G/14.5G [15:31<00:38, 12.8MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▌| 14.0G/14.5G [15:32<00:39, 12.3MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▌| 14.0G/14.5G [15:33<00:39, 12.2MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▌| 14.0G/14.5G [15:34<00:37, 12.5MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▌| 14.0G/14.5G [15:35<00:35, 12.7MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [15:35<00:34, 13.0MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [15:36<00:32, 13.3MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [15:37<00:31, 13.5MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [15:38<00:30, 13.6MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [15:38<00:29, 13.7MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [15:39<00:28, 13.8MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [15:40<00:27, 13.9MB/s]
#
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [15:41<00:26, 14.0MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▋| 14.1G/14.5G [15:41<00:25, 14.1MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▋| 14.1G/14.5G [15:42<00:24, 14.1MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▋| 14.2G/14.5G [15:43<00:23, 14.2MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▋| 14.2G/14.5G [15:43<00:22, 14.4MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▋| 14.2G/14.5G [15:44<00:21, 14.6MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▋| 14.2G/14.5G [15:45<00:20, 14.8MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▊| 14.2G/14.5G [15:45<00:19, 15.2MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▊| 14.2G/14.5G [15:46<00:18, 15.6MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▊| 14.2G/14.5G [15:47<00:17, 16.1MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▊| 14.2G/14.5G [15:47<00:15, 16.8MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▊| 14.2G/14.5G [15:48<00:14, 17.4MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▊| 14.3G/14.5G [15:48<00:13, 18.3MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▊| 14.3G/14.5G [15:49<00:12, 19.0MB/s]
#
#
#
# consolidated.safetensors:  98%|███████████▊| 14.3G/14.5G [15:49<00:11, 19.3MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [15:50<00:10, 21.1MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [15:50<00:09, 22.2MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [15:51<00:08, 23.0MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [15:51<00:07, 24.2MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [15:51<00:06, 25.4MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [15:52<00:06, 23.4MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [15:52<00:05, 29.0MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [15:52<00:04, 28.7MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [15:53<00:04, 28.7MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [15:53<00:04, 27.5MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [15:54<00:04, 26.7MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [15:54<00:03, 26.6MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [15:54<00:03, 26.9MB/s]
#
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [15:55<00:02, 27.2MB/s]
#
#
#
# consolidated.safetensors: 100%|███████████▉| 14.4G/14.5G [15:55<00:02, 27.6MB/s]
#
#
#
# consolidated.safetensors: 100%|███████████▉| 14.4G/14.5G [15:55<00:02, 28.3MB/s]
#
#
#
# consolidated.safetensors: 100%|███████████▉| 14.4G/14.5G [15:56<00:01, 28.6MB/s]
#
#
#
# consolidated.safetensors: 100%|███████████▉| 14.5G/14.5G [15:56<00:01, 28.9MB/s]
#
#
#
# consolidated.safetensors: 100%|███████████▉| 14.5G/14.5G [15:56<00:00, 29.6MB/s]
#
#
#
# consolidated.safetensors: 100%|███████████▉| 14.5G/14.5G [15:57<00:00, 29.8MB/s]
#
#
#
# consolidated.safetensors: 100%|███████████▉| 14.5G/14.5G [15:57<00:00, 30.4MB/s]
#
#
#
# consolidated.safetensors: 100%|████████████| 14.5G/14.5G [15:57<00:00, 15.1MB/s]
# Download complete. Moving file to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3/consolidated.safetensors
# Fetching 15 files: 100%|████████████████████████| 15/15 [15:58<00:00, 63.88s/it]
# /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/Mistral-7B-Instruct-v0.3

# %% [markdown]
# ### Step 3.3: Huggingface Model Conversion to MLX format

# %%
#In this block of code, I am trying to understand the arguments that are provided by the MLX community regarding the conversion of the original huggingface model format to MLX format

# !mlx_lm.convert --help
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# usage: mlx_lm.convert [-h] [--hf-path HF_PATH] [--mlx-path MLX_PATH] [-q]
#                       [--q-group-size Q_GROUP_SIZE] [--q-bits Q_BITS]
#                       [--dtype {float16,bfloat16,float32}]
#                       [--upload-repo UPLOAD_REPO] [-d]
#
# Convert Hugging Face model to MLX format
#
# options:
#   -h, --help            show this help message and exit
#   --hf-path HF_PATH     Path to the Hugging Face model.
#   --mlx-path MLX_PATH   Path to save the MLX model.
#   -q, --quantize        Generate a quantized model.
#   --q-group-size Q_GROUP_SIZE
#                         Group size for quantization.
#   --q-bits Q_BITS       Bits per weight for quantization.
#   --dtype {float16,bfloat16,float32}
#                         Type to save the non-quantized parameters.
#   --upload-repo UPLOAD_REPO
#                         The Hugging Face repo to upload the model to.
#   -d, --dequantize      Dequantize a quantized model.

# %%
#The code block below tackles the process of converting a model from the huggingface website into MLX format for further use.
#The variables used here in this code block are from Step 4.1 above.

# !mlx_lm.convert \
    --hf-path {hf_model} \
    --mlx-path {mlx_path}
# Out:
# [INFO] Loading
# Fetching 12 files:   0%|                                 | 0/12 [00:00<?, ?it/s]
# model.safetensors.index.json: 100%|████████| 23.9k/23.9k [00:00<00:00, 70.6MB/s]
#
# config.json: 100%|█████████████████████████████| 601/601 [00:00<00:00, 6.38MB/s]
#
# params.json: 100%|█████████████████████████████| 202/202 [00:00<00:00, 2.50MB/s]
# Fetching 12 files:   8%|██                       | 1/12 [00:00<00:02,  4.19it/s]
# generation_config.json: 100%|██████████████████| 116/116 [00:00<00:00, 1.76MB/s]
#
# model-00002-of-00003.safetensors:   0%|             | 0.00/5.00G [00:00<?, ?B/s]
#
# model-00001-of-00003.safetensors:   0%|             | 0.00/4.95G [00:00<?, ?B/s]
#
#
# consolidated.safetensors:   0%|                     | 0.00/14.5G [00:00<?, ?B/s]
#
#
#
# model-00003-of-00003.safetensors:   0%|             | 0.00/4.55G [00:00<?, ?B/s]
#
#
#
#
# special_tokens_map.json: 100%|█████████████████| 414/414 [00:00<00:00, 3.42MB/s]
#
#
#
#
#
# tokenizer.json:   0%|                               | 0.00/1.96M [00:00<?, ?B/s]
#
#
#
#
#
# tokenizer.model:   0%|                               | 0.00/587k [00:00<?, ?B/s]
#
#
#
#
#
#
# tokenizer_config.json: 100%|█████████████████| 141k/141k [00:00<00:00, 1.42MB/s]
#
#
#
#
#
#
# tokenizer.model: 100%|███████████████████████| 587k/587k [00:00<00:00, 2.20MB/s]
#
#
#
#
# model-00003-of-00003.safetensors:   0%|    | 10.5M/4.55G [00:00<04:15, 17.7MB/s]
# model-00002-of-00003.safetensors:   0%|    | 10.5M/5.00G [00:00<04:47, 17.3MB/s]
#
#
# consolidated.safetensors:   0%|            | 10.5M/14.5G [00:00<15:23, 15.7MB/s]
#
# model-00001-of-00003.safetensors:   0%|    | 10.5M/4.95G [00:00<07:45, 10.6MB/s]
# model-00002-of-00003.safetensors:   0%|    | 21.0M/5.00G [00:01<06:32, 12.7MB/s]
#
#
#
# model-00003-of-00003.safetensors:   0%|    | 21.0M/4.55G [00:01<06:39, 11.3MB/s]
#
#
# consolidated.safetensors:   0%|            | 21.0M/14.5G [00:02<27:03, 8.92MB/s]
# model-00002-of-00003.safetensors:   1%|    | 31.5M/5.00G [00:02<06:09, 13.4MB/s]
#
#
#
#
# tokenizer.json: 100%|███████████████████████| 1.96M/1.96M [00:02<00:00, 863kB/s]
#
#
# model-00001-of-00003.safetensors:   0%|    | 21.0M/4.95G [00:02<10:52, 7.55MB/s]
#
#
#
# model-00003-of-00003.safetensors:   1%|    | 31.5M/4.55G [00:02<07:04, 10.6MB/s]
# model-00002-of-00003.safetensors:   1%|    | 41.9M/5.00G [00:03<05:52, 14.1MB/s]
# model-00002-of-00003.safetensors:   1%|    | 52.4M/5.00G [00:03<04:55, 16.7MB/s]
#
#
# consolidated.safetensors:   0%|            | 31.5M/14.5G [00:03<27:30, 8.77MB/s]
#
#
#
# model-00003-of-00003.safetensors:   1%|    | 41.9M/4.55G [00:03<06:13, 12.1MB/s]
#
# model-00001-of-00003.safetensors:   1%|    | 31.5M/4.95G [00:03<09:49, 8.34MB/s]
# model-00002-of-00003.safetensors:   1%|    | 62.9M/5.00G [00:03<04:24, 18.7MB/s]
#
#
#
# model-00003-of-00003.safetensors:   1%|    | 52.4M/4.55G [00:04<05:25, 13.8MB/s]
# model-00002-of-00003.safetensors:   1%|    | 73.4M/5.00G [00:04<04:04, 20.2MB/s]
#
#
# consolidated.safetensors:   0%|            | 41.9M/14.5G [00:04<25:45, 9.35MB/s]
#
#
#
# model-00003-of-00003.safetensors:   1%|    | 62.9M/4.55G [00:04<05:15, 14.2MB/s]
# model-00002-of-00003.safetensors:   2%|    | 83.9M/5.00G [00:04<03:59, 20.6MB/s]
#
# model-00001-of-00003.safetensors:   1%|    | 41.9M/4.95G [00:04<09:40, 8.45MB/s]
#
#
#
# model-00003-of-00003.safetensors:   2%|    | 73.4M/4.55G [00:05<04:51, 15.4MB/s]
# model-00002-of-00003.safetensors:   2%|    | 94.4M/5.00G [00:05<04:11, 19.5MB/s]
#
#
#
# model-00003-of-00003.safetensors:   2%|    | 83.9M/4.55G [00:05<04:20, 17.2MB/s]
#
#
# consolidated.safetensors:   0%|            | 52.4M/14.5G [00:05<28:24, 8.47MB/s]
# model-00002-of-00003.safetensors:   2%|     | 105M/5.00G [00:05<04:14, 19.2MB/s]
#
# model-00001-of-00003.safetensors:   1%|    | 52.4M/4.95G [00:06<09:16, 8.80MB/s]
#
#
#
# model-00003-of-00003.safetensors:   2%|    | 94.4M/4.55G [00:06<04:01, 18.5MB/s]
# model-00002-of-00003.safetensors:   2%|     | 115M/5.00G [00:06<04:05, 19.9MB/s]
#
#
#
# model-00003-of-00003.safetensors:   2%|     | 105M/4.55G [00:06<03:51, 19.2MB/s]
# model-00002-of-00003.safetensors:   3%|▏    | 126M/5.00G [00:06<04:05, 19.9MB/s]
#
# model-00001-of-00003.safetensors:   1%|    | 62.9M/4.95G [00:07<08:40, 9.38MB/s]
#
#
#
# model-00003-of-00003.safetensors:   3%|▏    | 115M/4.55G [00:07<03:41, 20.0MB/s]
# model-00002-of-00003.safetensors:   3%|▏    | 136M/5.00G [00:07<03:43, 21.7MB/s]
#
#
# consolidated.safetensors:   0%|            | 62.9M/14.5G [00:07<30:55, 7.78MB/s]
#
#
#
# model-00003-of-00003.safetensors:   3%|▏    | 126M/4.55G [00:07<03:36, 20.4MB/s]
# model-00002-of-00003.safetensors:   3%|▏    | 147M/5.00G [00:07<03:31, 22.9MB/s]
#
# model-00001-of-00003.safetensors:   1%|    | 73.4M/4.95G [00:07<08:11, 9.93MB/s]
# model-00002-of-00003.safetensors:   3%|▏    | 157M/5.00G [00:08<03:23, 23.8MB/s]
#
#
#
# model-00003-of-00003.safetensors:   3%|▏    | 136M/4.55G [00:08<03:30, 21.0MB/s]
# model-00002-of-00003.safetensors:   3%|▏    | 168M/5.00G [00:08<03:24, 23.7MB/s]
#
#
#
# model-00003-of-00003.safetensors:   3%|▏    | 147M/4.55G [00:08<03:29, 21.0MB/s]
# model-00002-of-00003.safetensors:   4%|▏    | 178M/5.00G [00:08<03:05, 25.9MB/s]
#
# model-00001-of-00003.safetensors:   2%|    | 83.9M/4.95G [00:09<08:33, 9.47MB/s]
#
#
#
# model-00003-of-00003.safetensors:   3%|▏    | 157M/4.55G [00:09<03:34, 20.5MB/s]
# model-00002-of-00003.safetensors:   4%|▏    | 189M/5.00G [00:09<03:08, 25.5MB/s]
#
#
# consolidated.safetensors:   1%|            | 73.4M/14.5G [00:09<34:57, 6.88MB/s]
#
#
#
# model-00003-of-00003.safetensors:   4%|▏    | 168M/4.55G [00:09<03:18, 22.1MB/s]
# model-00002-of-00003.safetensors:   4%|▏    | 199M/5.00G [00:09<02:55, 27.3MB/s]
# model-00002-of-00003.safetensors:   4%|▏    | 210M/5.00G [00:10<03:00, 26.6MB/s]
#
#
#
# model-00003-of-00003.safetensors:   4%|▏    | 178M/4.55G [00:10<03:32, 20.6MB/s]
#
# model-00001-of-00003.safetensors:   2%|    | 94.4M/4.95G [00:10<08:47, 9.21MB/s]
# model-00002-of-00003.safetensors:   4%|▏    | 220M/5.00G [00:10<02:57, 26.9MB/s]
#
#
#
# model-00003-of-00003.safetensors:   4%|▏    | 189M/4.55G [00:10<03:17, 22.0MB/s]
# model-00002-of-00003.safetensors:   5%|▏    | 231M/5.00G [00:10<03:15, 24.5MB/s]
#
#
# consolidated.safetensors:   1%|            | 83.9M/14.5G [00:11<36:24, 6.60MB/s]
#
#
#
# model-00003-of-00003.safetensors:   4%|▏    | 199M/4.55G [00:11<03:33, 20.4MB/s]
# model-00002-of-00003.safetensors:   5%|▏    | 241M/5.00G [00:11<03:07, 25.4MB/s]
# model-00002-of-00003.safetensors:   5%|▎    | 252M/5.00G [00:11<03:24, 23.3MB/s]
#
#
#
# model-00003-of-00003.safetensors:   5%|▏    | 210M/4.55G [00:11<03:51, 18.7MB/s]
#
#
# consolidated.safetensors:   1%|            | 94.4M/14.5G [00:11<31:41, 7.58MB/s]
# model-00002-of-00003.safetensors:   5%|▎    | 262M/5.00G [00:12<02:52, 27.5MB/s]
#
# model-00001-of-00003.safetensors:   2%|     | 105M/4.95G [00:12<10:14, 7.89MB/s]
#
#
#
# model-00003-of-00003.safetensors:   5%|▏    | 220M/4.55G [00:12<03:38, 19.8MB/s]
# model-00002-of-00003.safetensors:   5%|▎    | 273M/5.00G [00:12<02:42, 29.1MB/s]
# model-00002-of-00003.safetensors:   6%|▎    | 283M/5.00G [00:12<02:44, 28.7MB/s]
#
#
# consolidated.safetensors:   1%|             | 105M/14.5G [00:12<28:08, 8.52MB/s]
#
#
#
# model-00003-of-00003.safetensors:   5%|▎    | 231M/4.55G [00:13<04:14, 16.9MB/s]
# model-00002-of-00003.safetensors:   6%|▎    | 294M/5.00G [00:13<03:11, 24.6MB/s]
#
#
# consolidated.safetensors:   1%|             | 115M/14.5G [00:13<22:57, 10.4MB/s]
# model-00002-of-00003.safetensors:   6%|▎    | 304M/5.00G [00:13<03:01, 25.8MB/s]
#
#
#
# model-00003-of-00003.safetensors:   5%|▎    | 241M/4.55G [00:13<04:31, 15.9MB/s]
#
#
# consolidated.safetensors:   1%|             | 126M/14.5G [00:14<21:04, 11.4MB/s]
# model-00002-of-00003.safetensors:   6%|▎    | 315M/5.00G [00:14<03:15, 24.0MB/s]
#
# model-00001-of-00003.safetensors:   2%|     | 115M/4.95G [00:14<12:36, 6.39MB/s]
# model-00002-of-00003.safetensors:   7%|▎    | 325M/5.00G [00:14<03:15, 23.9MB/s]
#
#
#
# model-00003-of-00003.safetensors:   6%|▎    | 252M/4.55G [00:14<04:48, 14.9MB/s]
# model-00002-of-00003.safetensors:   7%|▎    | 336M/5.00G [00:14<02:59, 25.9MB/s]
#
#
# consolidated.safetensors:   1%|             | 136M/14.5G [00:15<21:20, 11.2MB/s]
# model-00002-of-00003.safetensors:   7%|▎    | 346M/5.00G [00:15<02:43, 28.5MB/s]
#
#
#
# model-00003-of-00003.safetensors:   6%|▎    | 262M/4.55G [00:15<04:27, 16.0MB/s]
# model-00002-of-00003.safetensors:   7%|▎    | 357M/5.00G [00:15<02:32, 30.4MB/s]
#
#
#
# model-00003-of-00003.safetensors:   6%|▎    | 273M/4.55G [00:15<04:10, 17.1MB/s]
# model-00002-of-00003.safetensors:   7%|▎    | 367M/5.00G [00:15<02:36, 29.7MB/s]
#
#
# consolidated.safetensors:   1%|▏            | 147M/14.5G [00:15<21:07, 11.3MB/s]
# model-00002-of-00003.safetensors:   8%|▍    | 377M/5.00G [00:16<02:32, 30.3MB/s]
#
#
#
# model-00003-of-00003.safetensors:   6%|▎    | 283M/4.55G [00:16<04:03, 17.5MB/s]
# model-00002-of-00003.safetensors:   8%|▍    | 388M/5.00G [00:16<02:44, 28.0MB/s]
#
# model-00001-of-00003.safetensors:   3%|▏    | 126M/4.95G [00:16<14:03, 5.72MB/s]
#
#
#
# model-00003-of-00003.safetensors:   6%|▎    | 294M/4.55G [00:16<04:03, 17.5MB/s]
#
#
# consolidated.safetensors:   1%|▏            | 157M/14.5G [00:17<22:34, 10.6MB/s]
# model-00002-of-00003.safetensors:   8%|▍    | 398M/5.00G [00:17<02:50, 27.0MB/s]
#
#
#
# model-00003-of-00003.safetensors:   7%|▎    | 304M/4.55G [00:17<03:42, 19.0MB/s]
# model-00002-of-00003.safetensors:   8%|▍    | 409M/5.00G [00:17<02:42, 28.3MB/s]
# model-00002-of-00003.safetensors:   8%|▍    | 419M/5.00G [00:17<02:30, 30.5MB/s]
#
#
#
# model-00003-of-00003.safetensors:   7%|▎    | 315M/4.55G [00:17<03:25, 20.6MB/s]
# model-00002-of-00003.safetensors:   9%|▍    | 430M/5.00G [00:18<02:30, 30.3MB/s]
#
#
#
# model-00003-of-00003.safetensors:   7%|▎    | 325M/4.55G [00:18<03:10, 22.2MB/s]
#
#
# consolidated.safetensors:   1%|▏            | 168M/14.5G [00:18<23:46, 10.0MB/s]
# model-00002-of-00003.safetensors:   9%|▍    | 440M/5.00G [00:18<02:21, 32.2MB/s]
#
#
#
# model-00003-of-00003.safetensors
5MB/s]
#
#
#
# model-00003-of-00003.safetensors:  23%|▉   | 1.05G/4.55G [00:42<02:01, 28.9MB/s]
# model-00002-of-00003.safetensors:  22%|▉   | 1.11G/5.00G [00:42<01:55, 33.8MB/s]
#
#
#
# model-00003-of-00003.safetensors:  23%|▉   | 1.06G/4.55G [00:42<02:02, 28.5MB/s]
# model-00002-of-00003.safetensors:  22%|▉   | 1.12G/5.00G [00:42<01:52, 34.3MB/s]
#
#
#
# model-00003-of-00003.safetensors:  24%|▉   | 1.07G/4.55G [00:42<02:02, 28.5MB/s]
# model-00002-of-00003.safetensors:  23%|▉   | 1.13G/5.00G [00:42<02:03, 31.3MB/s]
#
#
# consolidated.safetensors:   2%|▏            | 262M/14.5G [00:42<54:09, 4.38MB/s]
#
#
#
# model-00003-of-00003.safetensors:  24%|▉   | 1.08G/4.55G [00:43<01:58, 29.2MB/s]
# model-00002-of-00003.safetensors:  23%|▉   | 1.14G/5.00G [00:43<02:05, 30.6MB/s]
#
#
#
# model-00003-of-00003.safetensors:  24%|▉   | 1.09G/4.55G [00:43<01:53, 30.4MB/s]
#
# model-00001-of-00003.safetensors:   4%|▏    | 220M/4.95G [00:43<18:51, 4.18MB/s]
#
#
#
# model-00003-of-00003.safetensors:  24%|▉   | 1.10G/4.55G [00:43<01:49, 31.5MB/s]
#
#
#
# model-00003-of-00003.safetensors:  24%|▉   | 1.11G/4.55G [00:44<01:50, 31.1MB/s]
#
#
# consolidated.safetensors:   2%|▏            | 273M/14.5G [00:44<46:21, 5.11MB/s]
#
#
#
# model-00003-of-00003.safetensors:  25%|▉   | 1.12G/4.55G [00:44<01:40, 34.0MB/s]
# model-00002-of-00003.safetensors:  23%|▉   | 1.15G/5.00G [00:44<03:24, 18.8MB/s]
#
# model-00001-of-00003.safetensors:   5%|▏    | 231M/4.95G [00:44<15:42, 5.01MB/s]
#
#
#
# model-00003-of-00003.safetensors:  25%|▉   | 1.13G/4.55G [00:44<01:50, 30.9MB/s]
#
#
#
# model-00003-of-00003.safetensors:  25%|█   | 1.14G/4.55G [00:45<01:45, 32.3MB/s]
#
#
# consolidated.safetensors:   2%|▎            | 283M/14.5G [00:45<38:41, 6.12MB/s]
#
#
#
# model-00003-of-00003.safetensors:  25%|█   | 1.15G/4.55G [00:45<01:39, 34.1MB/s]
# model-00002-of-00003.safetensors:  23%|▉   | 1.16G/5.00G [00:45<04:02, 15.8MB/s]
#
#
#
# model-00003-of-00003.safetensors:  26%|█   | 1.16G/4.55G [00:45<01:34, 35.7MB/s]
#
# model-00001-of-00003.safetensors:   5%|▏    | 241M/4.95G [00:45<13:49, 5.67MB/s]
#
#
# consolidated.safetensors:   2%|▎            | 294M/14.5G [00:45<31:46, 7.45MB/s]
# model-00002-of-00003.safetensors:  23%|▉   | 1.17G/5.00G [00:45<03:55, 16.3MB/s]
#
#
#
# model-00003-of-00003.safetensors:  26%|█   | 1.17G/4.55G [00:46<02:08, 26.3MB/s]
# model-00002-of-00003.safetensors:  24%|▉   | 1.18G/5.00G [00:46<03:47, 16.8MB/s]
#
#
#
# model-00003-of-00003.safetensors:  26%|█   | 1.18G/4.55G [00:46<02:03, 27.1MB/s]
#
#
# consolidated.safetensors:   2%|▎            | 304M/14.5G [00:46<27:40, 8.55MB/s]
#
#
#
# model-00003-of-00003.safetensors:  26%|█   | 1.20G/4.55G [00:47<02:21, 23.7MB/s]
# model-00002-of-00003.safetensors:  24%|▉   | 1.20G/5.00G [00:47<03:51, 16.5MB/s]
#
# model-00001-of-00003.safetensors:   5%|▎    | 252M/4.95G [00:47<13:10, 5.94MB/s]
#
#
#
# model-00003-of-00003.safetensors:  27%|█   | 1.21G/4.55G [00:47<02:10, 25.6MB/s]
# model-00002-of-00003.safetensors:  24%|▉   | 1.21G/5.00G [00:47<03:29, 18.1MB/s]
#
#
# consolidated.safetensors:   2%|▎            | 315M/14.5G [00:47<25:58, 9.10MB/s]
#
#
#
# model-00003-of-00003.safetensors:  27%|█   | 1.22G/4.55G [00:47<01:59, 27.8MB/s]
# model-00002-of-00003.safetensors:  24%|▉   | 1.22G/5.00G [00:48<03:15, 19.4MB/s]
#
#
#
# model-00003-of-00003.safetensors:  27%|█   | 1.23G/4.55G [00:48<01:59, 27.7MB/s]
#
#
#
# model-00003-of-00003.safetensors:  27%|█   | 1.24G/4.55G [00:48<01:48, 30.4MB/s]
#
#
# consolidated.safetensors:   2%|▎            | 325M/14.5G [00:48<23:55, 9.87MB/s]
# model-00002-of-00003.safetensors:  25%|▉   | 1.23G/5.00G [00:48<03:05, 20.3MB/s]
#
#
#
# model-00003-of-00003.safetensors:  27%|█   | 1.25G/4.55G [00:48<01:53, 29.2MB/s]
#
# model-00001-of-00003.safetensors:   5%|▎    | 262M/4.95G [00:48<12:24, 6.30MB/s]
# model-00002-of-00003.safetensors:  25%|▉   | 1.24G/5.00G [00:49<03:13, 19.4MB/s]
#
#
#
# model-00003-of-00003.safetensors:  28%|█   | 1.26G/4.55G [00:49<01:58, 27.8MB/s]
#
#
#
# model-00003-of-00003.safetensors:  28%|█   | 1.27G/4.55G [00:49<01:51, 29.3MB/s]
#
#
# consolidated.safetensors:   2%|▎            | 336M/14.5G [00:49<24:07, 9.78MB/s]
# model-00002-of-00003.safetensors:  25%|▉   | 1.25G/5.00G [00:49<03:18, 18.9MB/s]
#
#
#
# model-00003-of-00003.safetensors:  28%|█▏  | 1.28G/4.55G [00:49<01:59, 27.2MB/s]
# model-00002-of-00003.safetensors:  25%|█   | 1.26G/5.00G [00:50<03:18, 18.8MB/s]
#
#
#
# model-00003-of-00003.safetensors:  28%|█▏  | 1.29G/4.55G [00:50<01:52, 29.0MB/s]
#
# model-00001-of-00003.safetensors:   6%|▎    | 273M/4.95G [00:50<12:02, 6.47MB/s]
#
#
#
# model-00003-of-00003.safetensors:  29%|█▏  | 1.30G/4.55G [00:50<01:57, 27.7MB/s]
#
#
# consolidated.safetensors:   2%|▎            | 346M/14.5G [00:50<24:32, 9.61MB/s]
# model-00002-of-00003.safetensors:  25%|█   | 1.27G/5.00G [00:50<03:14, 19.2MB/s]
#
#
#
# model-00003-of-00003.safetensors:  29%|█▏  | 1.31G/4.55G [00:50<01:49, 29.6MB/s]
# model-00002-of-00003.safetensors:  26%|█   | 1.28G/5.00G [00:51<03:02, 20.4MB/s]
#
#
#
# model-00003-of-00003.safetensors:  29%|█▏  | 1.32G/4.55G [00:51<01:44, 30.8MB/s]
#
# model-00001-of-00003.safetensors:   6%|▎    | 283M/4.95G [00:51<11:05, 7.01MB/s]
#
#
# consolidated.safetensors:   2%|▎            | 357M/14.5G [00:51<22:59, 10.3MB/s]
#
#
#
# model-00003-of-00003.safetensors:  29%|█▏  | 1.33G/4.55G [00:51<01:41, 31.8MB/s]
# model-00002-of-00003.safetensors:  26%|█   | 1.29G/5.00G [00:51<02:54, 21.2MB/s]
#
#
#
# model-00003-of-00003.safetensors:  30%|█▏  | 1.34G/4.55G [00:51<01:38, 32.6MB/s]
# model-00002-of-00003.safetensors:  26%|█   | 1.30G/5.00G [00:52<02:57, 20.8MB/s]
#
#
#
# model-00003-of-00003.safetensors:  30%|█▏  | 1.35G/4.55G [00:52<01:41, 31.4MB/s]
#
#
# consolidated.safetensors:   3%|▎            | 367M/14.5G [00:52<22:27, 10.5MB/s]
#
#
#
# model-00003-of-00003.safetensors:  30%|█▏  | 1.36G/4.55G [00:52<01:42, 30.9MB/s]
# model-00002-of-00003.safetensors:  26%|█   | 1.31G/5.00G [00:52<02:53, 21.2MB/s]
#
# model-00001-of-00003.safetensors:   6%|▎    | 294M/4.95G [00:52<10:22, 7.48MB/s]
#
#
#
# model-00003-of-00003.safetensors:  30%|█▏  | 1.37G/4.55G [00:53<01:59, 26.5MB/s]
# model-00002-of-00003.safetensors:  26%|█   | 1.32G/5.00G [00:53<03:08, 19.5MB/s]
#
#
#
# model-00003-of-00003.safetensors:  30%|█▏  | 1.38G/4.55G [00:53<01:55, 27.3MB/s]
# model-00002-of-00003.safetensors:  27%|█   | 1.33G/5.00G [00:53<02:58, 20.5MB/s]
#
#
# consolidated.safetensors:   3%|▎            | 377M/14.5G [00:53<24:32, 9.59MB/s]
#
# model-00001-of-00003.safetensors:   6%|▎    | 304M/4.95G [00:53<09:40, 8.00MB/s]
#
#
#
# model-00003-of-00003.safetensors:  31%|█▏  | 1.39G/4.55G [00:53<01:52, 27.9MB/s]
#
#
#
# model-00003-of-00003.safetensors:  31%|█▏  | 1.41G/4.55G [00:54<01:48, 29.0MB/s]
# model-00002-of-00003.safetensors:  27%|█   | 1.34G/5.00G [00:54<02:55, 20.9MB/s]
#
#
#
# model-00003-of-00003.safetensors:  31%|█▏  | 1.42G/4.55G [00:54<01:51, 28.1MB/s]
# model-00002-of-00003.safetensors:  27%|█   | 1.35G/5.00G [00:54<03:01, 20.1MB/s]
#
# model-00001-of-00003.safetensors:   6%|▎    | 315M/4.95G [00:54<08:59, 8.59MB/s]
#
#
#
# model-00003-of-00003.safetensors:  31%|█▎  | 1.43G/4.55G [00:54<01:50, 28.3MB/s]
# model-00002-of-00003.safetensors:  27%|█   | 1.36G/5.00G [00:55<02:56, 20.6MB/s]
#
#
#
# model-00003-of-00003.safetensors:  32%|█▎  | 1.44G/4.55G [00:55<01:52, 27.7MB/s]
#
#
# consolidated.safetensors:   3%|▎            | 388M/14.5G [00:55<27:41, 8.49MB/s]
#
#
#
# model-00003-of-00003.safetensors:  32%|█▎  | 1.45G/4.55G [00:55<01:50, 28.1MB/s]
#
# model-00001-of-00003.safetensors:   7%|▎    | 325M/4.95G [00:55<08:18, 9.27MB/s]
# model-00002-of-00003.safetensors:  27%|█   | 1.37G/5.00G [00:55<03:09, 19.1MB/s]
#
#
#
# model-00003-of-00003.safetensors:  32%|█▎  | 1.46G/4.55G [00:56<01:44, 29.4MB/s]
#
#
#
# model-00003-of-00003.safetensors:  32%|█▎  | 1.47G/4.55G [00:56<01:40, 30.7MB/s]
# model-00002-of-00003.safetensors:  28%|█   | 1.38G/5.00G [00:56<03:17, 18.3MB/s]
#
#
# consolidated.safetensors:   3%|▎            | 398M/14.5G [00:56<28:19, 8.29MB/s]
#
#
#
# model-00003-of-00003.safetensors:  33%|█▎  | 1.48G/4.55G [00:56<01:44, 29.4MB/s]
#
# model-00001-of-00003.safetensors:   7%|▎    | 336M/4.95G [00:56<07:56, 9.69MB/s]
#
#
#
# model-00003-of-00003.safetensors:  33%|█▎  | 1.49G/4.55G [00:57<01:41, 30.1MB/s]
# model-00002-of-00003.safetensors:  28%|█   | 1.39G/5.00G [00:57<03:25, 17.6MB/s]
#
#
#
# model-00003-of-00003.safetensors:  33%|█▎  | 1.50G/4.55G [00:57<01:41, 30.1MB/s]
#
# model-00001-of-00003.safetensors:   7%|▎    | 346M/4.95G [00:57<07:07, 10.8MB/s]
#
#
# consolidated.safetensors:   3%|▎            | 409M/14.5G [00:57<25:49, 9.09MB/s]
# model-00002-of-00003.safetensors:  28%|█   | 1.41G/5.00G [00:57<03:23, 17.6MB/s]
#
#
#
# model-00003-of-00003.safetensors:  33%|█▎  | 1.51G/4.55G [00:57<01:45, 28.9MB/s]
#
#
#
# model-00003-of-00003.safetensors:  33%|█▎  | 1.52G/4.55G [00:58<01:56, 26.0MB/s]
# model-00002-of-00003.safetensors:  28%|█▏  | 1.42G/5.00G [00:58<03:18, 18.0MB/s]
#
# model-00001-of-00003.safetensors:   7%|▎    | 357M/4.95G [00:58<07:12, 10.6MB/s]
#
#
# consolidated.safetensors:   3%|▍            | 419M/14.5G [00:58<25:53, 9.06MB/s]
# model-00002-of-00003.safetensors:  29%|█▏  | 1.43G/5.00G [00:58<03:24, 17.4MB/s]
#
#
#
# model-00003-of-00003.safetensors:  
B/s]
#
#
# consolidated.safetensors:  89%|██████████▋ | 12.9G/14.5G [08:07<00:37, 42.8MB/s]
#
#
# consolidated.safetensors:  89%|██████████▋ | 12.9G/14.5G [08:07<00:36, 43.3MB/s]
#
#
# consolidated.safetensors:  89%|██████████▋ | 12.9G/14.5G [08:07<00:36, 43.1MB/s]
#
#
# consolidated.safetensors:  89%|██████████▋ | 12.9G/14.5G [08:08<00:36, 43.3MB/s]
#
#
# consolidated.safetensors:  89%|██████████▋ | 12.9G/14.5G [08:08<00:36, 43.0MB/s]
#
#
# consolidated.safetensors:  89%|██████████▋ | 12.9G/14.5G [08:08<00:36, 42.7MB/s]
#
#
# consolidated.safetensors:  89%|██████████▋ | 12.9G/14.5G [08:08<00:35, 43.0MB/s]
#
#
# consolidated.safetensors:  89%|██████████▋ | 13.0G/14.5G [08:09<00:35, 42.9MB/s]
#
#
# consolidated.safetensors:  89%|██████████▋ | 13.0G/14.5G [08:09<00:35, 42.9MB/s]
#
#
# consolidated.safetensors:  90%|██████████▋ | 13.0G/14.5G [08:09<00:35, 42.8MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.0G/14.5G [08:09<00:35, 42.9MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.0G/14.5G [08:10<00:40, 36.9MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.0G/14.5G [08:10<00:33, 43.7MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.0G/14.5G [08:10<00:32, 45.1MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.0G/14.5G [08:10<00:32, 44.5MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.0G/14.5G [08:11<00:33, 44.0MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.1G/14.5G [08:11<00:32, 43.8MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.1G/14.5G [08:11<00:32, 43.7MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.1G/14.5G [08:11<00:32, 43.5MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.1G/14.5G [08:12<00:32, 43.3MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.1G/14.5G [08:12<00:32, 43.3MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.1G/14.5G [08:12<00:32, 43.2MB/s]
#
#
# consolidated.safetensors:  90%|██████████▊ | 13.1G/14.5G [08:12<00:32, 42.8MB/s]
#
#
# consolidated.safetensors:  91%|██████████▊ | 13.1G/14.5G [08:13<00:31, 42.9MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.1G/14.5G [08:13<00:31, 43.1MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.1G/14.5G [08:13<00:31, 43.1MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.2G/14.5G [08:13<00:31, 42.9MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.2G/14.5G [08:14<00:30, 43.0MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.2G/14.5G [08:14<00:30, 42.6MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.2G/14.5G [08:14<00:30, 42.6MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.2G/14.5G [08:14<00:30, 42.8MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.2G/14.5G [08:15<00:30, 42.8MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.2G/14.5G [08:15<00:29, 42.9MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.2G/14.5G [08:15<00:29, 42.9MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.2G/14.5G [08:15<00:29, 43.1MB/s]
#
#
# consolidated.safetensors:  91%|██████████▉ | 13.3G/14.5G [08:16<00:28, 43.0MB/s]
#
#
# consolidated.safetensors:  92%|██████████▉ | 13.3G/14.5G [08:16<00:28, 43.0MB/s]
#
#
# consolidated.safetensors:  92%|██████████▉ | 13.3G/14.5G [08:16<00:28, 42.9MB/s]
#
#
# consolidated.safetensors:  92%|██████████▉ | 13.3G/14.5G [08:16<00:28, 42.8MB/s]
#
#
# consolidated.safetensors:  92%|███████████ | 13.3G/14.5G [08:16<00:27, 43.1MB/s]
#
#
# consolidated.safetensors:  92%|███████████ | 13.3G/14.5G [08:17<00:27, 42.9MB/s]
#
#
# consolidated.safetensors:  92%|███████████ | 13.3G/14.5G [08:17<00:27, 42.8MB/s]
#
#
# consolidated.safetensors:  92%|███████████ | 13.3G/14.5G [08:17<00:27, 43.2MB/s]
#
#
# consolidated.safetensors:  92%|███████████ | 13.3G/14.5G [08:17<00:26, 43.0MB/s]
#
#
# consolidated.safetensors:  92%|███████████ | 13.3G/14.5G [08:18<00:26, 43.0MB/s]
#
#
# consolidated.safetensors:  92%|███████████ | 13.4G/14.5G [08:18<00:26, 42.9MB/s]
#
#
# consolidated.safetensors:  92%|███████████ | 13.4G/14.5G [08:18<00:26, 43.0MB/s]
#
#
# consolidated.safetensors:  92%|███████████ | 13.4G/14.5G [08:18<00:25, 43.2MB/s]
#
#
# consolidated.safetensors:  92%|███████████ | 13.4G/14.5G [08:19<00:25, 43.0MB/s]
#
#
# consolidated.safetensors:  92%|███████████ | 13.4G/14.5G [08:19<00:25, 43.1MB/s]
#
#
# consolidated.safetensors:  93%|███████████ | 13.4G/14.5G [08:19<00:25, 43.1MB/s]
#
#
# consolidated.safetensors:  93%|███████████ | 13.4G/14.5G [08:19<00:24, 43.1MB/s]
#
#
# consolidated.safetensors:  93%|███████████ | 13.4G/14.5G [08:20<00:24, 43.1MB/s]
#
#
# consolidated.safetensors:  93%|███████████▏| 13.4G/14.5G [08:20<00:27, 37.7MB/s]
#
#
# consolidated.safetensors:  93%|███████████▏| 13.5G/14.5G [08:20<00:23, 44.8MB/s]
#
#
# consolidated.safetensors:  93%|███████████▏| 13.5G/14.5G [08:20<00:23, 44.4MB/s]
#
#
# consolidated.safetensors:  93%|███████████▏| 13.5G/14.5G [08:21<00:23, 44.0MB/s]
#
#
# consolidated.safetensors:  93%|███████████▏| 13.5G/14.5G [08:21<00:23, 43.7MB/s]
#
#
# consolidated.safetensors:  93%|███████████▏| 13.5G/14.5G [08:21<00:22, 43.7MB/s]
#
#
# consolidated.safetensors:  93%|███████████▏| 13.5G/14.5G [08:21<00:22, 43.6MB/s]
#
#
# consolidated.safetensors:  93%|███████████▏| 13.5G/14.5G [08:22<00:22, 43.3MB/s]
#
#
# consolidated.safetensors:  93%|███████████▏| 13.5G/14.5G [08:22<00:22, 43.2MB/s]
#
#
# consolidated.safetensors:  93%|███████████▏| 13.5G/14.5G [08:22<00:22, 43.3MB/s]
#
#
# consolidated.safetensors:  93%|███████████▏| 13.5G/14.5G [08:22<00:21, 43.2MB/s]
#
#
# consolidated.safetensors:  94%|███████████▏| 13.6G/14.5G [08:23<00:21, 43.1MB/s]
#
#
# consolidated.safetensors:  94%|███████████▏| 13.6G/14.5G [08:23<00:21, 42.9MB/s]
#
#
# consolidated.safetensors:  94%|███████████▏| 13.6G/14.5G [08:23<00:21, 43.0MB/s]
#
#
# consolidated.safetensors:  94%|███████████▏| 13.6G/14.5G [08:23<00:21, 42.6MB/s]
#
#
# consolidated.safetensors:  94%|███████████▎| 13.6G/14.5G [08:24<00:20, 42.7MB/s]
#
#
# consolidated.safetensors:  94%|███████████▎| 13.6G/14.5G [08:24<00:20, 42.7MB/s]
#
#
# consolidated.safetensors:  94%|███████████▎| 13.6G/14.5G [08:24<00:20, 42.6MB/s]
#
#
# consolidated.safetensors:  94%|███████████▎| 13.6G/14.5G [08:24<00:20, 42.7MB/s]
#
#
# consolidated.safetensors:  94%|███████████▎| 13.6G/14.5G [08:25<00:19, 42.7MB/s]
#
#
# consolidated.safetensors:  94%|███████████▎| 13.7G/14.5G [08:25<00:20, 42.0MB/s]
#
#
# consolidated.safetensors:  94%|███████████▎| 13.7G/14.5G [08:25<00:19, 43.2MB/s]
#
#
# consolidated.safetensors:  94%|███████████▎| 13.7G/14.5G [08:25<00:20, 39.6MB/s]
#
#
# consolidated.safetensors:  94%|███████████▎| 13.7G/14.5G [08:26<00:20, 40.6MB/s]
#
#
# consolidated.safetensors:  94%|███████████▎| 13.7G/14.5G [08:26<00:19, 41.4MB/s]
#
#
# consolidated.safetensors:  95%|███████████▎| 13.7G/14.5G [08:26<00:18, 41.9MB/s]
#
#
# consolidated.safetensors:  95%|███████████▎| 13.7G/14.5G [08:26<00:18, 42.0MB/s]
#
#
# consolidated.safetensors:  95%|███████████▎| 13.7G/14.5G [08:27<00:18, 42.5MB/s]
#
#
# consolidated.safetensors:  95%|███████████▎| 13.7G/14.5G [08:27<00:17, 42.4MB/s]
#
#
# consolidated.safetensors:  95%|███████████▍| 13.7G/14.5G [08:27<00:17, 42.6MB/s]
#
#
# consolidated.safetensors:  95%|███████████▍| 13.8G/14.5G [08:27<00:17, 42.7MB/s]
#
#
# consolidated.safetensors:  95%|███████████▍| 13.8G/14.5G [08:28<00:17, 42.7MB/s]
#
#
# consolidated.safetensors:  95%|███████████▍| 13.8G/14.5G [08:28<00:16, 42.8MB/s]
#
#
# consolidated.safetensors:  95%|███████████▍| 13.8G/14.5G [08:28<00:16, 42.8MB/s]
#
#
# consolidated.safetensors:  95%|███████████▍| 13.8G/14.5G [08:28<00:16, 42.7MB/s]
#
#
# consolidated.safetensors:  95%|███████████▍| 13.8G/14.5G [08:29<00:16, 42.7MB/s]
#
#
# consolidated.safetensors:  95%|███████████▍| 13.8G/14.5G [08:29<00:15, 42.6MB/s]
#
#
# consolidated.safetensors:  95%|███████████▍| 13.8G/14.5G [08:29<00:15, 42.5MB/s]
#
#
# consolidated.safetensors:  95%|███████████▍| 13.8G/14.5G [08:29<00:15, 42.7MB/s]
#
#
# consolidated.safetensors:  96%|███████████▍| 13.9G/14.5G [08:30<00:15, 42.9MB/s]
#
#
# consolidated.safetensors:  96%|███████████▍| 13.9G/14.5G [08:30<00:14, 43.0MB/s]
#
#
# consolidated.safetensors:  96%|███████████▍| 13.9G/14.5G [08:30<00:14, 42.8MB/s]
#
#
# consolidated.safetensors:  96%|███████████▍| 13.9G/14.5G [08:30<00:14, 43.1MB/s]
#
#
# consolidated.safetensors:  96%|███████████▌| 13.9G/14.5G [08:30<00:13, 43.1MB/s]
#
#
# consolidated.safetensors:  96%|███████████▌| 13.9G/14.5G [08:31<00:13, 43.1MB/s]
#
#
# consolidated.safetensors:  96%|███████████▌| 13.9G/14.5G [08:31<00:13, 43.1MB/s]
#
#
# consolidated.safetensors:  96%|███████████▌| 13.9G/14.5G [08:31<00:13, 43.3MB/s]
#
#
# consolidated.safetensors:  96%|███████████▌| 13.9G/14.5G [08:31<00:12, 43.3MB/s]
#
#
# consolidated.safetensors:  96%|███████████▌| 13.9G/14.5G [08:32<00:15, 35.6MB/s]
#
#
# consolidated.safetensors:  96%|███████████▌| 14.0G/14.5G [08:32<00:13, 41.0MB/s]
#
#
# consolidated.safetensors:  96%|███████████▌| 14.0G/14.5G [08:32<00:11, 46.4MB/s]
#
#
# consolidated.safetensors:  96%|███████████▌| 14.0G/14.5G [08:32<00:11, 45.4MB/s]
#
#
# consolidated.safetensors:  96%|███████████▌| 14.0G/14.5G [08:33<00:11, 44.5MB/s]
#
#
# consolidated.safetensors:  97%|███████████▌| 14.0G/14.5G [08:33<00:11, 44.3MB/s]
#
#
# consolidated.safetensors:  97%|███████████▌| 14.0G/14.5G [08:33<00:11, 43.8MB/s]
#
#
# consolidated.safetensors:  97%|███████████▌| 14.0G/14.5G [08:33<00:10, 43.5MB/s]
#
#
# consolidated.safetensors:  97%|███████████▌| 14.0G/14.5G [08:34<00:10, 43.5MB/s]
#
#
# consolidated.safetensors:  97%|███████████▌| 14.0G/14.5G [08:34<00:10, 43.3MB/s]
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [08:34<00:10, 43.1MB/s]
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [08:34<00:10, 43.1MB/s]
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [08:35<00:09, 43.1MB/s]
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [08:35<00:09, 43.4MB/s]
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [08:35<00:09, 43.1MB/s]
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [08:35<00:09, 41.2MB/s]
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [08:36<00:09, 41.7MB/s]
#
#
# consolidated.safetensors:  97%|███████████▋| 14.1G/14.5G [08:36<00:08, 42.1MB/s]
#
#
# consolidated.safetensors:  98%|███████████▋| 14.1G/14.5G [08:36<00:08, 42.3MB/s]
#
#
# consolidated.safetensors:  98%|███████████▋| 14.1G/14.5G [08:36<00:08, 42.4MB/s]
#
#
# consolidated.safetensors:  98%|███████████▋| 14.2G/14.5G [08:37<00:08, 40.3MB/s]
#
#
# consolidated.safetensors:  98%|███████████▋| 14.2G/14.5G [08:37<00:08, 41.0MB/s]
#
#
# consolidated.safetensors:  98%|███████████▋| 14.2G/14.5G [08:37<00:07, 41.3MB/s]
#
#
# consolidated.safetensors:  98%|███████████▋| 14.2G/14.5G [08:37<00:07, 41.8MB/s]
#
#
# consolidated.safetensors:  98%|███████████▊| 14.2G/14.5G [08:38<00:07, 41.4MB/s]
#
#
# consolidated.safetensors:  98%|███████████▊| 14.2G/14.5G [08:38<00:06, 41.9MB/s]
#
#
# consolidated.safetensors:  98%|███████████▊| 14.2G/14.5G [08:38<00:06, 43.0MB/s]
#
#
# consolidated.safetensors:  98%|███████████▊| 14.2G/14.5G [08:38<00:06, 43.0MB/s]
#
#
# consolidated.safetensors:  98%|███████████▊| 14.2G/14.5G [08:39<00:05, 42.8MB/s]
#
#
# consolidated.safetensors:  98%|███████████▊| 14.3G/14.5G [08:39<00:05, 43.0MB/s]
#
#
# consolidated.safetensors:  98%|███████████▊| 14.3G/14.5G [08:39<00:05, 42.9MB/s]
#
#
# consolidated.safetensors:  98%|███████████▊| 14.3G/14.5G [08:39<00:05, 42.9MB/s]
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [08:40<00:04, 43.1MB/s]
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [08:40<00:04, 43.1MB/s]
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [08:40<00:04, 43.0MB/s]
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [08:40<00:04, 42.8MB/s]
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [08:41<00:04, 42.8MB/s]
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [08:41<00:03, 42.9MB/s]
#
#
# consolidated.safetensors:  99%|███████████▊| 14.3G/14.5G [08:41<00:03, 42.9MB/s]
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [08:41<00:03, 43.0MB/s]
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [08:42<00:03, 42.9MB/s]
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [08:42<00:02, 43.0MB/s]
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [08:42<00:02, 43.1MB/s]
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [08:42<00:02, 43.0MB/s]
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [08:43<00:02, 42.9MB/s]
#
#
# consolidated.safetensors:  99%|███████████▉| 14.4G/14.5G [08:43<00:01, 43.0MB/s]
#
#
# consolidated.safetensors: 100%|███████████▉| 14.4G/14.5G [08:43<00:01, 42.9MB/s]
#
#
# consolidated.safetensors: 100%|███████████▉| 14.4G/14.5G [08:43<00:01, 43.0MB/s]
#
#
# consolidated.safetensors: 100%|███████████▉| 14.4G/14.5G [08:44<00:01, 43.1MB/s]
#
#
# consolidated.safetensors: 100%|███████████▉| 14.5G/14.5G [08:44<00:00, 43.1MB/s]
#
#
# consolidated.safetensors: 100%|███████████▉| 14.5G/14.5G [08:44<00:00, 43.2MB/s]
#
#
# consolidated.safetensors: 100%|███████████▉| 14.5G/14.5G [08:44<00:00, 43.1MB/s]
#
#
# consolidated.safetensors: 100%|███████████▉| 14.5G/14.5G [08:44<00:00, 43.2MB/s]
#
#
# consolidated.safetensors: 100%|████████████| 14.5G/14.5G [08:45<00:00, 27.6MB/s]
# Fetching 12 files: 100%|████████████████████████| 12/12 [08:45<00:00, 43.78s/it]

# %% [markdown]
# ### Step 3.4: Undertaking the fine-tuning of the chosen model using the Low Rank Adaptation under MLX_LM
#
# In this step, I am trying to make the best use of the Low Rank Adaptation with mlx_lm.lora under the mlx_lm package to fine-tune the already converted MLX Mistral V0.3

# %%
#In this block of code, I am trying to understand the arguments that are provided by the MLX community regarding the LoRA fine-tuning to a desired model

! mlx_lm.lora --help
# Out:
# usage: mlx_lm.lora [-h] [--model MODEL] [--train] [--data DATA]
#                    [--fine-tune-type {lora,dora,full}]
#                    [--num-layers NUM_LAYERS] [--batch-size BATCH_SIZE]
#                    [--iters ITERS] [--val-batches VAL_BATCHES]
#                    [--learning-rate LEARNING_RATE]
#                    [--steps-per-report STEPS_PER_REPORT]
#                    [--steps-per-eval STEPS_PER_EVAL]
#                    [--resume-adapter-file RESUME_ADAPTER_FILE]
#                    [--adapter-path ADAPTER_PATH] [--save-every SAVE_EVERY]
#                    [--test] [--test-batches TEST_BATCHES]
#                    [--max-seq-length MAX_SEQ_LENGTH] [-c CONFIG]
#                    [--grad-checkpoint] [--seed SEED]
#
# LoRA or QLoRA finetuning.
#
# options:
#   -h, --help            show this help message and exit
#   --model MODEL         The path to the local model directory or Hugging Face
#                         repo.
#   --train               Do training
#   --data DATA           Directory with {train, valid, test}.jsonl files or the
#                         name of a Hugging Face dataset (e.g., 'mlx-
#                         community/wikisql')
#   --fine-tune-type {lora,dora,full}
#                         Type of fine-tuning to perform: lora, dora, or full.
#   --num-layers NUM_LAYERS
#                         Number of layers to fine-tune. Default is 16, use -1
#                         for all.
#   --batch-size BATCH_SIZE
#                         Minibatch size.
#   --iters ITERS         Iterations to train for.
#   --val-batches VAL_BATCHES
#                         Number of validation batches, -1 uses the entire
#                         validation set.
#   --learning-rate LEARNING_RATE
#                         Adam learning rate.
#   --steps-per-report STEPS_PER_REPORT
#                         Number of training steps between loss reporting.
#   --steps-per-eval STEPS_PER_EVAL
#                         Number of training steps between validations.
#   --resume-adapter-file RESUME_ADAPTER_FILE
#                         Load path to resume training from the given fine-tuned
#                         weights.
#   --adapter-path ADAPTER_PATH
#                         Save/load path for the fine-tuned weights.
#   --save-every SAVE_EVERY
#                         Save the model every N iterations.
#   --test                Evaluate on the test set after training
#   --test-batches TEST_BATCHES
#                         Number of test set batches, -1 uses the entire test
#                         set.
#   --max-seq-length MAX_SEQ_LENGTH
#                         Maximum sequence length.
#   -c CONFIG, --config CONFIG
#                         A YAML configuration file with the training options
#   --grad-checkpoint     Use gradient checkpointing to reduce memory use.
#   --seed SEED           The PRNG seed

# %%
# Fine-tuning a Large Language Model using MLX framework optimized for Apple Silicon
# Detailed parameter explanations:

# --model ${mlx_path}
# Purpose: Specifies the base model path for fine-tuning
# Benefit: Allows building upon pre-trained knowledge, saving time and computational resources

# --train
# Purpose: Activates the training mode
# Benefit: Distinguishes between inference and training, enabling model updates

# --data ${data}
# Purpose: Points to the training dataset location which contains the 3 data files: train.jsonl, test.jsonl and valid.jsonl
# Benefit: Provides the model with task-specific examples to learn from

# --fine-tune-type lora
# Purpose: Implements LoRA (Low-Rank Adaptation) method
# Benefit: Reduces memory usage and training time while maintaining performance by updating only a small subset of parameters

# --num-layers 16
# Purpose: Defines the number of transformer layers to fine-tune
# Benefit: Controls the depth of model adaptation, balancing between performance and computational efficiency

# --batch-size 8
# Purpose: Sets number of examples processed simultaneously
# Benefit: Optimizes memory usage and training stability for Apple Silicon chips

# --iters 1000
# Purpose: Defines total training iterations
# Benefit: Ensures sufficient model adaptation while preventing overfitting

# --val-batches 50
# Purpose: Specifies validation batch count
# Benefit: Enables monitoring of model generalization and prevents overfitting

# --learning-rate 1e-5
# Purpose: Controls the size of parameter updates
# Benefit: Small value helps preserve base model knowledge while learning new tasks

# --steps-per-report 10
# Purpose: Sets frequency of progress updates
# Benefit: Allows monitoring training progress without excessive logging

# --steps-per-eval 200
# Purpose: Determines evaluation frequency
# Benefit: Regular performance checks without significant training slowdown

# --adapter-path ${adapters}
# Purpose: Specifies where to save LoRA weights
# Benefit: Enables reuse and sharing of fine-tuned adaptations

# --save-every 500
# Purpose: Sets checkpoint frequency
# Benefit: Prevents loss of progress in case of interruptions

# --max-seq-length 2048
# Purpose: Limits input sequence length
# Benefit: Balances between context window and memory usage

# --grad-checkpoint
# Purpose: Enables gradient checkpointing
# Benefit: Reduces memory usage by recomputing intermediate values during backpropagation

# --seed 42
# Purpose: Sets random number generator seed
# Benefit: Ensures reproducibility of training results

! mlx_lm.lora \
 --model ${mlx_path} \
 --train \
 --data ${data} \
 --fine-tune-type lora \
 --num-layers 16 \
 --batch-size 8 \
 --iters 200 \
 --val-batches 4 \
 --learning-rate 2e-5 \
 --steps-per-report 10 \
 --steps-per-eval 50 \
 --adapter-path ${adapters} \
 --save-every 100 \
 --max-seq-length 2048 \
 --grad-checkpoint \
 --seed 42

 # Rationale for the arguments above:
# num--layers: Normally anywhere between 40% to 80% of the total number of layers in the model. In my case the model has 32 layers so I chose 16 layers to be fine-tuned.
# batch-size: I choose 16 to be more stable for gradient stability. People normally use 8 if they do not have a vision on what is the optimum batch size.
# iters: Since MLX do not provie epochs as an argument then I will have to choose the best number of iterations that yields 5-8 epochs in my case. The dataset is composed of circa 500 records. So the epochs= 200 iterations x batch size 16 / 500 records = 6.4 epochs. I chose 200 iterations to be in the range of 5-8 epochs.
# learning-rate: I chose 2e-5 as it is a good learning rate that is not too high to forget the base model knowledge and not too low to make the training very slow. The normal range would be 2e-5 to 4e-5.
# max-seq-length: I choose 2048 as I did the calculations on the number of tokens in my dataset for each question and answer and each data entry does not exceed 200 tokens so 2,000 will be more than enough for both questions from the users and answers to be provided by the model.
# val-batches : The equation is val-batches x batch-size / number of records = number of validation records. I chose 4 validation batches x 16 batch size / 500 records = circa 10% of the data to be used for validation which is a good practice.
# steps-per-eval: the equation for it is max(50,iters//10). In my case the equation would be max(50,250//10)=50. I chose 50 as it is a good number to evaluate the model frequently without overloading the training process.
# save-every: I chose 100 as you have to have a least 4 checkpoints during the training process. But in my case I have only 200 iterations so I am going to have 4 checkpoints which is still acceptable (at 50 Steps, 100 steps, 150 Steps & 200 steps).
# Out:
# Loading pretrained model
# Loading datasets
# Training
# Trainable parameters: 0.047% (3.408M/7248.024M)
# Starting training..., iters: 1000
# Iter 1: Val loss 3.905, Val took 9.424s
# Iter 10: Train loss 3.213, Learning Rate 1.000e-05, It/sec 0.204, Tokens/sec 282.654, Trained Tokens 13874, Peak mem 18.217 GB
# Iter 20: Train loss 2.555, Learning Rate 1.000e-05, It/sec 0.240, Tokens/sec 284.678, Trained Tokens 25742, Peak mem 18.217 GB
# Iter 30: Train loss 2.347, Learning Rate 1.000e-05, It/sec 0.161, Tokens/sec 279.264, Trained Tokens 43084, Peak mem 20.094 GB
# Iter 40: Train loss 2.225, Learning Rate 1.000e-05, It/sec 0.188, Tokens/sec 282.106, Trained Tokens 58107, Peak mem 20.094 GB
# Iter 50: Train loss 2.177, Learning Rate 1.000e-05, It/sec 0.179, Tokens/sec 267.087, Trained Tokens 73045, Peak mem 20.094 GB
# Iter 60: Train loss 2.147, Learning Rate 1.000e-05, It/sec 0.188, Tokens/sec 286.998, Trained Tokens 88279, Peak mem 20.094 GB
# Iter 70: Train loss 2.094, Learning Rate 1.000e-05, It/sec 0.238, Tokens/sec 286.638, Trained Tokens 100327, Peak mem 20.094 GB
# Iter 80: Train loss 2.041, Learning Rate 1.000e-05, It/sec 0.198, Tokens/sec 285.668, Trained Tokens 114784, Peak mem 20.094 GB
# Iter 90: Train loss 2.060, Learning Rate 1.000e-05, It/sec 0.161, Tokens/sec 274.361, Trained Tokens 131813, Peak mem 20.094 GB
# Iter 100: Train loss 1.946, Learning Rate 1.000e-05, It/sec 0.249, Tokens/sec 285.572, Trained Tokens 143268, Peak mem 20.094 GB
# Iter 110: Train loss 1.966, Learning Rate 1.000e-05, It/sec 0.200, Tokens/sec 280.226, Trained Tokens 157277, Peak mem 20.094 GB
# Iter 120: Train loss 1.964, Learning Rate 1.000e-05, It/sec 0.155, Tokens/sec 264.662, Trained Tokens 174380, Peak mem 20.094 GB
# Iter 130: Train loss 1.910, Learning Rate 1.000e-05, It/sec 0.210, Tokens/sec 275.910, Trained Tokens 187530, Peak mem 20.094 GB
# Iter 140: Train loss 1.917, Learning Rate 1.000e-05, It/sec 0.175, Tokens/sec 270.626, Trained Tokens 203032, Peak mem 20.094 GB
# Iter 150: Train loss 1.900, Learning Rate 1.000e-05, It/sec 0.167, Tokens/sec 260.801, Trained Tokens 218640, Peak mem 20.094 GB
# Iter 160: Train loss 1.809, Learning Rate 1.000e-05, It/sec 0.211, Tokens/sec 270.903, Trained Tokens 231472, Peak mem 20.094 GB
# Iter 170: Train loss 1.720, Learning Rate 1.000e-05, It/sec 0.222, Tokens/sec 270.225, Trained Tokens 243655, Peak mem 20.094 GB
# Iter 180: Train loss 1.745, Learning Rate 1.000e-05, It/sec 0.213, Tokens/sec 273.215, Trained Tokens 256464, Peak mem 20.094 GB
# Iter 190: Train loss 1.770, Learning Rate 1.000e-05, It/sec 0.170, Tokens/sec 257.242, Trained Tokens 271617, Peak mem 20.094 GB
# Iter 200: Val loss 2.162, Val took 10.148s
# Iter 200: Train loss 1.836, Learning Rate 1.000e-05, It/sec 2.535, Tokens/sec 3891.546, Trained Tokens 286969, Peak mem 20.094 GB
# Iter 210: Train loss 1.641, Learning Rate 1.000e-05, It/sec 0.193, Tokens/sec 269.650, Trained Tokens 300945, Peak mem 20.094 GB
# Iter 220: Train loss 1.738, Learning Rate 1.000e-05, It/sec 0.156, Tokens/sec 250.418, Trained Tokens 316984, Peak mem 20.094 GB
# Iter 230: Train loss 1.719, Learning Rate 1.000e-05, It/sec 0.194, Tokens/sec 272.990, Trained Tokens 331074, Peak mem 20.094 GB
# Iter 240: Train loss 1.581, Learning Rate 1.000e-05, It/sec 0.207, Tokens/sec 272.304, Trained Tokens 344257, Peak mem 20.094 GB
# Iter 250: Train loss 1.595, Learning Rate 1.000e-05, It/sec 0.176, Tokens/sec 264.018, Trained Tokens 359226, Peak mem 20.094 GB
# Iter 260: Train loss 1.638, Learning Rate 1.000e-05, It/sec 0.162, Tokens/sec 250.796, Trained Tokens 374741, Peak mem 20.094 GB
# Iter 270: Train loss 1.549, Learning Rate 1.000e-05, It/sec 0.183, Tokens/sec 255.643, Trained Tokens 388734, Peak mem 20.094 GB
# Iter 280: Train loss 1.425, Learning Rate 1.000e-05, It/sec 0.208, Tokens/sec 269.184, Trained Tokens 401645, Peak mem 20.094 GB
# Iter 290: Train loss 1.442, Learning Rate 1.000e-05, It/sec 0.206, Tokens/sec 267.868, Trained Tokens 414647, Peak mem 20.094 GB
# Iter 300: Train loss 1.653, Learning Rate 1.000e-05, It/sec 0.146, Tokens/sec 256.727, Trained Tokens 432215, Peak mem 20.094 GB
# Iter 310: Train loss 1.352, Learning Rate 1.000e-05, It/sec 0.208, Tokens/sec 271.495, Trained Tokens 445274, Peak mem 20.094 GB
# Iter 320: Train loss 1.358, Learning Rate 1.000e-05, It/sec 0.223, Tokens/sec 267.550, Trained Tokens 457267, Peak mem 20.094 GB
# Iter 330: Train loss 1.525, Learning Rate 1.000e-05, It/sec 0.147, Tokens/sec 254.844, Trained Tokens 474570, Peak mem 20.094 GB
# Iter 340: Train loss 1.296, Learning Rate 1.000e-05, It/sec 0.194, Tokens/sec 272.393, Trained Tokens 488579, Peak mem 20.094 GB
# Iter 350: Train loss 1.410, Learning Rate 1.000e-05, It/sec 0.164, Tokens/sec 260.840, Trained Tokens 504526, Peak mem 20.094 GB
# Iter 360: Train loss 1.222, Learning Rate 1.000e-05, It/sec 0.234, Tokens/sec 274.971, Trained Tokens 516261, Peak mem 20.094 GB
# Iter 370: Train loss 1.330, Learning Rate 1.000e-05, It/sec 0.169, Tokens/sec 261.081, Trained Tokens 531698, Peak mem 20.094 GB
# Iter 380: Train loss 1.200, Learning Rate 1.000e-05, It/sec 0.211, Tokens/sec 279.419, Trained Tokens 544922, Peak mem 20.094 GB
# Iter 390: Train loss 1.327, Learning Rate 1.000e-05, It/sec 0.177, Tokens/sec 280.326, Trained Tokens 560794, Peak mem 20.094 GB
# Iter 400: Val loss 2.584, Val took 9.871s
# Iter 400: Train loss 1.219, Learning Rate 1.000e-05, It/sec 2.630, Tokens/sec 3795.307, Trained Tokens 575226, Peak mem 20.094 GB
# Iter 410: Train loss 1.088, Learning Rate 1.000e-05, It/sec 0.206, Tokens/sec 278.271, Trained Tokens 588762, Peak mem 20.094 GB
# Iter 420: Train loss 1.177, Learning Rate 1.000e-05, It/sec 0.198, Tokens/sec 265.428, Trained Tokens 602177, Peak mem 20.094 GB
# Iter 430: Train loss 1.250, Learning Rate 1.000e-05, It/sec 0.164, Tokens/sec 260.093, Trained Tokens 617994, Peak mem 20.094 GB
# Iter 440: Train loss 1.137, Learning Rate 1.000e-05, It/sec 0.174, Tokens/sec 269.917, Trained Tokens 633472, Peak mem 20.094 GB
# Iter 450: Train loss 1.085, Learning Rate 1.000e-05, It/sec 0.167, Tokens/sec 254.420, Trained Tokens 648686, Peak mem 20.094 GB
# Iter 460: Train loss 1.068, Learning Rate 1.000e-05, It/sec 0.198, Tokens/sec 268.603, Trained Tokens 662228, Peak mem 20.094 GB
# Iter 470: Train loss 0.984, Learning Rate 1.000e-05, It/sec 0.183, Tokens/sec 267.978, Trained Tokens 676865, Peak mem 20.094 GB
# Iter 480: Train loss 0.886, Learning Rate 1.000e-05, It/sec 0.216, Tokens/sec 269.197, Trained Tokens 689340, Peak mem 20.094 GB
# Iter 490: Train loss 0.998, Learning Rate 1.000e-05, It/sec 0.175, Tokens/sec 252.487, Trained Tokens 703742, Peak mem 20.094 GB
# Iter 500: Train loss 1.065, Learning Rate 1.000e-05, It/sec 0.175, Tokens/sec 270.448, Trained Tokens 719182, Peak mem 20.094 GB
# Iter 500: Saved adapter weights to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/RICS_APC_Finetuning/adapters/adapters.safetensors and /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/RICS_APC_Finetuning/adapters/0000500_adapters.safetensors.
# Iter 510: Train loss 0.845, Learning Rate 1.000e-05, It/sec 0.200, Tokens/sec 268.465, Trained Tokens 732598, Peak mem 20.094 GB
# Iter 520: Train loss 0.859, Learning Rate 1.000e-05, It/sec 0.195, Tokens/sec 267.663, Trained Tokens 746316, Peak mem 20.094 GB
# Iter 530: Train loss 1.046, Learning Rate 1.000e-05, It/sec 0.163, Tokens/sec 257.347, Trained Tokens 762143, Peak mem 20.108 GB
# Iter 540: Train loss 0.805, Learning Rate 1.000e-05, It/sec 0.175, Tokens/sec 253.912, Trained Tokens 776656, Peak mem 20.108 GB
# Iter 550: Train loss 0.856, Learning Rate 1.000e-05, It/sec 0.186, Tokens/sec 270.139, Trained Tokens 791183, Peak mem 20.108 GB
# Iter 560: Train loss 0.870, Learning Rate 1.000e-05, It/sec 0.190, Tokens/sec 265.345, Trained Tokens 805119, Peak mem 20.108 GB
# Iter 570: Train loss 0.852, Learning Rate 1.000e-05, It/sec 0.167, Tokens/sec 269.933, Trained Tokens 821319, Peak mem 20.108 GB
# Iter 580: Train loss 0.727, Learning Rate 1.000e-05, It/sec 0.193, Tokens/sec 250.708, Trained Tokens 834312, Peak mem 20.108 GB
# Iter 590: Train loss 0.814, Learning Rate 1.000e-05, It/sec 0.182, Tokens/sec 268.194, Trained Tokens 849082, Peak mem 20.108 GB
# Iter 600: Val loss 3.105, Val took 10.293s
# Iter 600: Train loss 0.665, Learning Rate 1.000e-05, It/sec 2.485, Tokens/sec 3217.717, Trained Tokens 862030, Peak mem 20.108 GB
# Iter 610: Train loss 0.628, Learning Rate 1.000e-05, It/sec 0.209, Tokens/sec 265.571, Trained Tokens 874764, Peak mem 20.108 GB
# Iter 620: Train loss 0.749, Learning Rate 1.000e-05, It/sec 0.185, Tokens/sec 266.771, Trained Tokens 889205, Peak mem 20.108 GB
# Iter 630: Train loss 0.847, Learning Rate 1.000e-05, It/sec 0.156, Tokens/sec 254.145, Trained Tokens 905447, Peak mem 20.108 GB
# Iter 640: Train loss 0.745, Learning Rate 1.000e-05, It/sec 0.169, Tokens/sec 266.695, Trained Tokens 921204, Peak mem 20.108 GB
# Iter 650: Train loss 0.638, Learning Rate 1.000e-05, It/sec 0.182, Tokens/sec 250.639, Trained Tokens 934973, Peak mem 20.108 GB
# Iter 660: Train loss 0.653, Learning Rate 1.000e-05, It/sec 0.188, Tokens/sec 266.943, Trained Tokens 949140, Peak mem 20.108 GB
# Iter 670: Train loss 0.527, Learning Rate 1.000e-05, It/sec 0.205, Tokens/sec 264.973, Trained Tokens 962067, Peak mem 20.108 GB
# Iter 680: Train loss 0.683, Learning Rate 1.000e-05, It/sec 0.177, Tokens/sec 264.152, Trained Tokens 976993, Peak mem 20.108 GB
# Iter 690: Train loss 0.695, Learning Rate 1.000e-05, It/sec 0.164, Tokens/sec 252.745, Trained Tokens 992395, Peak mem 20.108 GB
# Iter 700: Train loss 0.593, Learning Rate 1.000e-05, It/sec 0.176, Tokens/sec 261.666, Trained Tokens 1007286, Peak mem 20.108 GB
# Iter 710: Train loss 0.540, Learning Rate 1.000e-05, It/sec 0.196, Tokens/sec 263.865, Trained Tokens 1020763, Peak mem 20.108 GB
# Iter 720: Train loss 0.615, Learning Rate 1.000e-05, It/sec 0.171, Tokens/sec 250.523, Trained Tokens 1035388, Peak mem 20.108 GB
# Iter 730: Train loss 0.543, Learning Rate 1.000e-05, It/sec 0.195, Tokens/sec 265.261, Trained Tokens 1048957, Peak mem 20.108 GB
# Iter 740: Train loss 0.646, Learning Rate 1.000e-05, It/sec 0.155, Tokens/sec 249.793, Trained Tokens 1065087, Peak mem 20.108 GB
# Iter 750: Train loss 0.499, Learning Rate 1.000e-05, It/sec 0.195, Tokens/sec 263.873, Trained Tokens 1078602, Peak mem 20.108 GB
# Iter 760: Train loss 0.594, Learning Rate 1.000e-05, It/sec 0.173, Tokens/sec 255.075, Trained Tokens 1093374, Peak mem 20.108 GB
# Iter 770: Train loss 0.492, Learning Rate 1.000e-05, It/sec 0.186, Tokens/sec 257.669, Trained Tokens 1107237, Peak mem 20.108 GB
# Iter 780: Train loss 0.561, Learning Rate 1.000e-05, It/sec 0.168, Tokens/sec 246.838, Trained Tokens 1121937, Peak mem 20.108 GB
# Iter 790: Train loss 0.502, Learning Rate 1.000e-05, It/sec 0.182, Tokens/sec 263.571, Trained Tokens 1136427, Peak mem 20.108 GB
# Iter 800: Val loss 3.514, Val took 10.411s
# Iter 800: Train loss 0.438, Learning Rate 1.000e-05, It/sec 1.443, Tokens/sec 2027.489, Trained Tokens 1150481, Peak mem 20.108 GB
# Iter 810: Train loss 0.411, Learning Rate 1.000e-05, It/sec 0.206, Tokens/sec 264.417, Trained Tokens 1163347, Peak mem 20.108 GB
# Iter 820: Train loss 0.520, Learning Rate 1.000e-05, It/sec 0.177, Tokens/sec 262.253, Trained Tokens 1178133, Peak mem 20.108 GB
# Iter 830: Train loss 0.498, Learning Rate 1.000e-05, It/sec 0.164, Tokens/sec 251.167, Trained Tokens 1193455, Peak mem 20.108 GB
# Iter 840: Train loss 0.553, Learning Rate 1.000e-05, It/sec 0.158, Tokens/sec 249.189, Trained Tokens 1209238, Peak mem 20.108 GB
# Iter 850: Train loss 0.317, Learning Rate 1.000e-05, It/sec 0.230, Tokens/sec 266.499, Trained Tokens 1220847, Peak mem 20.108 GB
# Iter 860: Train loss 0.529, Learning Rate 1.000e-05, It/sec 0.157, Tokens/sec 264.009, Trained Tokens 1237618, Peak mem 20.108 GB
# Iter 870: Train loss 0.372, Learning Rate 1.000e-05, It/sec 0.204, Tokens/sec 261.864, Trained Tokens 1250449, Peak mem 20.108 GB
# Iter 880: Train loss 0.322, Learning Rate 1.000e-05, It/sec 0.225, Tokens/sec 261.679, Trained Tokens 1262083, Peak mem 20.108 GB
# Iter 890: Train loss 0.586, Learning Rate 1.000e-05, It/sec 0.140, Tokens/sec 252.146, Trained Tokens 1280070, Peak mem 20.108 GB
# Iter 900: Train loss 0.299, Learning Rate 1.000e-05, It/sec 0.228, Tokens/sec 263.348, Trained Tokens 1291626, Peak mem 20.108 GB
# Iter 910: Train loss 0.326, Learning Rate 1.000e-05, It/sec 0.213, Tokens/sec 264.607, Trained Tokens 1304031, Peak mem 20.108 GB
# Iter 920: Train loss 0.445, Learning Rate 1.000e-05, It/sec 0.168, Tokens/sec 262.954, Trained Tokens 1319692, Peak mem 20.108 GB
# Iter 930: Train loss 0.552, Learning Rate 1.000e-05, It/sec 0.135, Tokens/sec 251.763, Trained Tokens 1338406, Peak mem 20.108 GB
# Iter 940: Train loss 0.386, Learning Rate 1.000e-05, It/sec 0.173, Tokens/sec 264.722, Trained Tokens 1353724, Peak mem 20.108 GB
# Iter 950: Train loss 0.377, Learning Rate 1.000e-05, It/sec 0.172, Tokens/sec 251.666, Trained Tokens 1368386, Peak mem 20.108 GB
# Iter 960: Train loss 0.324, Learning Rate 1.000e-05, It/sec 0.203, Tokens/sec 257.080, Trained Tokens 1381032, Peak mem 20.108 GB
# Iter 970: Train loss 0.403, Learning Rate 1.000e-05, It/sec 0.169, Tokens/sec 258.984, Trained Tokens 1396314, Peak mem 20.108 GB
# Iter 980: Train loss 0.316, Learning Rate 1.000e-05, It/sec 0.211, Tokens/sec 261.653, Trained Tokens 1408729, Peak mem 20.108 GB
# Iter 990: Train loss 0.380, Learning Rate 1.000e-05, It/sec 0.166, Tokens/sec 248.350, Trained Tokens 1423710, Peak mem 20.108 GB
# Iter 1000: Val loss 3.853, Val took 10.451s
# Iter 1000: Train loss 0.285, Learning Rate 1.000e-05, It/sec 2.349, Tokens/sec 3044.652, Trained Tokens 1436671, Peak mem 20.108 GB
# Iter 1000: Saved adapter weights to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/RICS_APC_Finetuning/adapters/adapters.safetensors and /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/RICS_APC_Finetuning/adapters/0001000_adapters.safetensors.
# Saved final weights to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/RICS_APC_Finetuning/adapters/adapters.safetensors.

# %% [markdown]
# ### Step 3.5: Testing the adapaters
#
# * In this step, I am doing the mathematical tests provided by the MLX community which include the **Loss** and the **Perplexity** tests.
#
# ### MLX Testing Metrics Analysis for Apple Silicon LLM Fine-tuning
#
# #### 3. Test Loss (3.945)
# * **Definition**: Cross-entropy loss measured on the test set
# * **Typical Range**: 1.5 to 5.0
# * **Interpretation**:
#   * < 2.5: Excellent performance
#   * 2.5-3.5: Good performance
#   * 3.5-4.5: Moderate performance
#   * ">" 4.5: Poor performance
# * **Current Value Assessment**: 3.945 indicates moderate performance
#
# #### 4. Test Perplexity (PPL) (51.684)
# * **Definition**: Exponential of the loss (e^loss)
# * **Purpose**: Measures model's uncertainty in predicting next tokens
# * **Typical Range**: 10 to 100
# * **Interpretation**:
#   * < 20: Excellent performance
#   * 20-40: Good performance
#   * 40-60: Moderate performance
#   * ">" 60: Poor performance
# * **Current Value Assessment**: 51.684 indicates moderate uncertainty in predictions
#
# ### Relationship Between Metrics
# * Loss and perplexity are exponentially related (PPL = e^loss)
# * Both metrics indicate prediction accuracy
# * Lower values indicate better performance
#
# ### Performance Assessment
# The current results suggest moderate performance with potential for improvement through:
# * Additional fine-tuning iterations
# * Hyperparameter optimization
# * Training data quality/quantity improvements
# * Model architecture adjustments
#
# ### Note
# These metrics provide quantitative measures of model performance and can guide optimization efforts during the fine-tuning process.

# %%
# Testing a Fine-tuned Large Language Model using MLX framework
# This command runs evaluation on a previously fine-tuned model using LoRA (Low-Rank Adaptation)

# Command breakdown with detailed explanations:

# --model ${mlx_path}
# Purpose: Specifies the path to either:
#   - A local model directory containing model files
#   - A Hugging Face repository name
# Benefit: Enables access to the base model for testing

# --data ${data}
# Purpose: Points to either:
#   - A directory containing test.jsonl file
#   - A Hugging Face dataset name (e.g., 'mlx-community/wikisql')
# Benefit: Provides test data to evaluate model performance

# --adapter-path ${adapters}
# Purpose: Specifies the location of previously trained LoRA weights
# Benefit: Loads the fine-tuned adaptations for evaluation
# Note: Essential for testing as it contains the task-specific learning

# --test
# Purpose: Activates test mode evaluation
# Benefit: Switches the model to evaluation mode and runs inference on test dataset
# Note: This differs from validation as it's meant for final performance assessment

! mlx_lm.lora \
 --model ${mlx_path} \
 --data ${data} \
 --adapter-path ${adapters} \
 --test
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Loading pretrained model
# Loading datasets
# Testing
# Test loss 3.945, Test ppl 51.684.

# %% [markdown]
# ### Step 3.6: Generating responses from the fine-tuned adapters
#
# Having tested the model above, it is now time to generate some responses to see how good the model really is.

# %%
# In this code block, I am trying to explore the main arguments of the generate function provided by the MLX library.

# !mlx_lm.generate --help
# Out:
# usage: mlx_lm.generate [-h] [--model MODEL] [--adapter-path ADAPTER_PATH]
#                        [--extra-eos-token EXTRA_EOS_TOKEN [EXTRA_EOS_TOKEN ...]]
#                        [--system-prompt SYSTEM_PROMPT] [--prompt PROMPT]
#                        [--max-tokens MAX_TOKENS] [--temp TEMP] [--top-p TOP_P]
#                        [--min-p MIN_P]
#                        [--min-tokens-to-keep MIN_TOKENS_TO_KEEP] [--seed SEED]
#                        [--ignore-chat-template] [--use-default-chat-template]
#                        [--verbose VERBOSE] [--max-kv-size MAX_KV_SIZE]
#                        [--prompt-cache-file PROMPT_CACHE_FILE]
#                        [--kv-bits KV_BITS] [--kv-group-size KV_GROUP_SIZE]
#                        [--quantized-kv-start QUANTIZED_KV_START]
#                        [--draft-model DRAFT_MODEL]
#                        [--num-draft-tokens NUM_DRAFT_TOKENS]
#
# LLM inference script
#
# options:
#   -h, --help            show this help message and exit
#   --model MODEL         The path to the local model directory or Hugging Face
#                         repo. If no model is specified, then mlx-
#                         community/Llama-3.2-3B-Instruct-4bit is used.
#   --adapter-path ADAPTER_PATH
#                         Optional path for the trained adapter weights and
#                         config.
#   --extra-eos-token EXTRA_EOS_TOKEN [EXTRA_EOS_TOKEN ...]
#                         Add tokens in the list of eos tokens that stop
#                         generation.
#   --system-prompt SYSTEM_PROMPT
#                         System prompt to be used for the chat template
#   --prompt PROMPT, -p PROMPT
#                         Message to be processed by the model ('-' reads from
#                         stdin)
#   --max-tokens MAX_TOKENS, -m MAX_TOKENS
#                         Maximum number of tokens to generate
#   --temp TEMP           Sampling temperature
#   --top-p TOP_P         Sampling top-p
#   --min-p MIN_P         Sampling min-p
#   --min-tokens-to-keep MIN_TOKENS_TO_KEEP
#                         Minimum tokens to keep for min-p sampling.
#   --seed SEED           PRNG seed
#   --ignore-chat-template
#                         Use the raw prompt without the tokenizer's chat
#                         template.
#   --use-default-chat-template
#                         Use the default chat template
#   --verbose VERBOSE     Log verbose output when 'True' or 'T' or only print
#                         the response when 'False' or 'F'
#   --max-kv-size MAX_KV_SIZE
#                         Set the maximum key-value cache size
#   --prompt-cache-file PROMPT_CACHE_FILE
#                         A file containing saved KV caches to avoid recomputing
#                         them
#   --kv-bits KV_BITS     Number of bits for KV cache quantization. Defaults to
#                         no quantization.
#   --kv-group-size KV_GROUP_SIZE
#                         Group size for KV cache quantization.
#   --quantized-kv-start QUANTIZED_KV_START
#                         When --kv-bits is set, start quantizing the KV cache
#                         from this step onwards.
#   --draft-model DRAFT_MODEL
#                         A model to be used for speculative decoding.
#   --num-draft-tokens NUM_DRAFT_TOKENS
#                         Number of tokens to draft when using speculative
#                         decoding.

# %%
# Generate text using a fine-tuned MLX model with specific parameters for RICS APC competency examples
# This command uses the model to generate responses with controlled parameters for consistent, high-quality output

# Detailed parameter breakdown:

# --model ${mlx_path}
# Purpose: Specifies the path to the base model (local directory or Hugging Face repo)
# Benefit: Provides the foundation model for generation

# --adapter-path ${adapters}
# Purpose: Points to the fine-tuned LoRA weights and configuration
# Benefit: Applies domain-specific knowledge learned during fine-tuning

# --system-prompt "${System_prompt}"
# Purpose: Sets the context and behavior instructions for the model
# Benefit: Guides the model to generate responses in the desired format and style

# --prompt "Give me a good quality example of competency Procurement and Tendering level 2"
# Purpose: The actual input query for the model
# Benefit: Requests specific competency example at the desired level

# --max-tokens 400
# Purpose: Limits the length of generated response to 400 tokens
# Benefit: Ensures responses are comprehensive but concise

# --temp 0.3
# Purpose: Sets temperature for text generation (lower value = more focused/deterministic outputs)
# Benefit: Low temperature (0.3) produces more consistent and conservative responses
# Note: Range is 0-1, where 0 is most deterministic and 1 is most creative

# --use-default-chat-template
# Purpose: Applies the model's built-in chat formatting template
# Benefit: Ensures proper formatting of inputs for optimal model understanding

# --verbose True
# Purpose: Enables detailed output logging
# Benefit: Provides visibility into the generation process and model behavior

#Here is an example prompt. Based on the RICS APC guidance notes, one could expect that level 2 is all about the doing of the work based on the knowledge from level 1.

# !mlx_lm.generate \
   --model ${mlx_path} \
   --adapter-path ${adapters} \
   --system-prompt "${System_prompt}" \
   --prompt "Give me a good quality quality example of competency Procurement and Tendering level 2 " \
   --max-tokens 400 \
   --temp  0.3 \
   --use-default-chat-template \
   --verbose True
# Out:
# ==========
# During my employment at my current employer/one of the companies that I worked in, I have been involved in a number of Procurement and Tendering routes including Single-Stage Tender, Two-Stage Tender, Negotiated Tender, Framework Agreement, and Selective Tendering.
# One of my recent projects was tendered using a Two-Stage Tender process. The first stage of the tender process required potential Contractors to submit a tender package containing a completed tender price statement, design and construction information, and health and safety information. Following the assessment of the tender submissions by a tender evaluation panel, four pre-qualified Contractors were invited to submit a second stage tender package containing a price change reflecting any amendments made to the tender documents, updated construction programme, and a tender cost summary in line with the tender brief. Following the assessment of the second stage tender submissions, a contract was awarded with one of the four pre-qualified Contractors.
# I have also been involved in the preparation of briefing documents for the Procurement team on a number of projects. These documents included Tender Briefing and Tender Document Checklists.
# I have also gained an understanding of the different Procurement routes including Traditional Procurement, Design and Build, Construction Management, and Management Contracting.
# ==========
# Prompt: 269 tokens, 631.665 tokens-per-sec
# Generation: 282 tokens, 22.400 tokens-per-sec
# Peak memory: 14.678 GB

# %%
# And here is another example prompt where I am tackling level 3 in a comptency. 
# Level 3 has to include advice based on doing the comptency in level 2 and building on the knowledge from level 1.

# !mlx_lm.generate \
    --model {mlx_path} \
    --adapter-path {adapters} \
    --system-prompt "{System_prompt}" \
    --prompt "Give me a good quality quality example of competency Procurement and Tendering level 3 " \
    --max-tokens 400 \
    --temp  0.3 \
    --use-default-chat-template \
    --verbose True
# Out:
# ==========
# I have been involved in a school expansion project where four school buildings were tendered separately. I have also worked on various local authority and private residential projects where a range of procurement routes were applied.
# In a project for a private residential development of a 12-unit apartment block, a design and build contract was adopted with a price per unit.
# In a residential project for a local authority, a two-stage contract was adopted with a design team in-house and fixed price for the first stage.
# I have gained experience in value management exercises, including the preparation of options, quantification of alternatives, and facilitation of workshops with the design and client team to identify opportunities to reduce the cost of the project while ensuring the same level of quality.
# I have worked on projects where contractual disputes occurred, including a school expansion project due to the non-release of payment certificates by the client.
# I have advised clients on the different procurement routes based on their requirements and budget.
# I have also advised clients on the importance of early engagement of key team members, value management exercises, and identifying risks at the early design stage.
# ==========
# Prompt: 269 tokens, 637.640 tokens-per-sec
# Generation: 237 tokens, 23.405 tokens-per-sec
# Peak memory: 14.678 GB

# %%
# And here is another example prompt where I am tackling level 3 in a comptency. 
# Level 3 has to include advice based on doing the comptency in level 2 and building on the knowledge from level 1.

# !mlx_lm.generate \
    --model {mlx_path} \
    --adapter-path {adapters} \
    --system-prompt "{System_prompt}" \
    --prompt "Give me a good quality quality example of competency: Contract Practice level 3 " \
    --max-tokens 400 \
    --temp  0.3 \
    --use-default-chat-template \
    --verbose True
# Out:
# ==========
# At a leisure development project that I worked on, I successfully negotiated a delay and liquidated damages clause with the client after carrying out a programme analysis on the construction programme which demonstrated that the employer risks were significantly high. I advised the client on the merits of taking the contractor to court versus negotiating with the client. I also drafted a proposed agreement.
# At a commercial office project that I advised, the contractor went into liquidation. I liaised with the client and advised on the options available such as engaging a new contractor or continuing with the existing design and progress. I also advised the client on the risks associated with continuing with the existing contractor works and drafted a closure order to bring the contract to an end.
# ==========
# Prompt: 264 tokens, 616.198 tokens-per-sec
# Generation: 155 tokens, 23.509 tokens-per-sec
# Peak memory: 14.676 GB

# %% [markdown]
# # Part IV - Saving the fused model with the trained adapters & compression to GGUF format
#
# In this part of the code we are going to explore how we can make the best use of the fuse functionlity under the MLX Library
#
# ### Step 4.1 - Fusing the MLX model with the trained adapters and saving it locally

# %%
#Understanding the different functionalities within the fuse python file under the MLX_LM
# !mlx_lm.fuse --help
# Out:
# Loading pretrained model
# usage: mlx_lm.fuse [-h] [--model MODEL] [--save-path SAVE_PATH]
#                    [--adapter-path ADAPTER_PATH] [--hf-path HF_PATH]
#                    [--upload-repo UPLOAD_REPO] [--de-quantize] [--export-gguf]
#                    [--gguf-path GGUF_PATH]
#
# Fuse fine-tuned adapters into the base model.
#
# options:
#   -h, --help            show this help message and exit
#   --model MODEL         The path to the local model directory or Hugging Face
#                         repo.
#   --save-path SAVE_PATH
#                         The path to save the fused model.
#   --adapter-path ADAPTER_PATH
#                         Path to the trained adapter weights and config.
#   --hf-path HF_PATH     Path to the original Hugging Face model. Required for
#                         upload if --model is a local directory.
#   --upload-repo UPLOAD_REPO
#                         The Hugging Face repo to upload the model to.
#   --de-quantize         Generate a de-quantized model.
#   --export-gguf         Export model weights in GGUF format.
#   --gguf-path GGUF_PATH
#                         Path to save the exported GGUF format model weights.
#                         Default is ggml-model-f16.gguf.

# %% [markdown]
# In the following block of code, I am trying to fuse the trained adapters with the MLX converted model after having seen the performance.
#
# Here is a full explanation of the code used below
#
# ##### 1. `--model ${mlx_path}`
# * **Purpose**: Specifies the location of the base model
# * **Options**:
#   * Local directory path
#   * Hugging Face repository name
# * **Importance**: Serves as the foundation model for fusion
#
# ##### 2. `--save-path ${output_directory}`
# * **Purpose**: Defines where the fused model will be saved
# * **Output**: Creates a new directory containing:
#   * Merged model weights
#   * Model configuration
#   * Tokenizer files
#
# ##### 3. `--adapter-path ${adapters}`
# * **Purpose**: Points to the LoRA adapter weights and configuration
# * **Content**: Contains:
#   * Fine-tuned weight adjustments
#   * Training configuration
# * **Role**: These weights will be merged with the base model
#
# ##### 4. `--de-quantize`
# * **Purpose**: Converts the model back to full precision
# * **Process**:
#   * Removes any quantization applied to the base model
#   * Returns weights to float32/float16 format
# * **Benefits**:
#   * Potentially improved accuracy
#   * Better compatibility with certain applications
# * **Trade-off**: Larger model size compared to quantized version
#
# #### Purpose of the Command
# This command performs three main operations:
# 1. Loads the original base model
# 2. Incorporates the fine-tuned LoRA adaptations
# 3. Creates a new, standalone model with merged weights in full precision
#
# #### Common Use Cases
# * Creating deployment-ready models
# * Preparing models for different platforms
# * Converting fine-tuned models to full precision
# * Generating models for scenarios requiring maximum accuracy
#
# #### Note
# The resulting model will:
# * Be larger in size due to de-quantization
# * Include all fine-tuned adaptations
# * Be ready for direct use without needing separate adapter loading

# %%
# !mlx_lm.fuse \
    --model {mlx_path} \
    --save-path {output_directory} \
    --adapter-path {adapters} \
    --de-quantize
# Out:
# Loading pretrained model
# De-quantizing model

# %% [markdown]
# ### Step 4.2: Testing the fused model for correctness
#
# In the code block below, I am testing the fused MLX model with the trained adapters to make sure that the model after the fuse process is behaving as it should.
#
# For this I am using the resultant MLX-finetuned model with the adaptes from Step 4.1 above.
#
# For further details about the mlx_lm.generate function, please refer to Step 3.6 above.

# %%
# !mlx_lm.generate \
    --model {output_directory} \
    --system-prompt "{System_prompt}" \
    --prompt "Give me a good quality quality example of competency: Construction Technology level 3 " \
    --max-tokens 400 \
    --temp  0.1 \
    --use-default-chat-template \
    --verbose True
# Out:
# ==========
# I have been involved in numerous projects where I had to advise the client on various matters relating to the construction of the building. For example, when reviewing the cost report prepared by the loss leader consultants on a commercial scheme, I was able to advise the client about the correctness of the figures being claimed by the claimant contractor and what construction methods were in accordance with local building regulations as opposed to the claimant entitlement to additional costs.
# I was able to further advise the client about the works which were within spec and which works were in accordance with the contract (both contract terms which were fair and reasonable, as well terms which were in line with current market terms). I have also been able to advise clients about the correct contractual wording which would class the works as both a change to the contract and/or change to the spec.
# I have been able to advise clients about the correct contractual wording required to establish whether the changes were within scope of the contract or not. I have also been able to advise clients about the correct contractual wording required to establish whether the changes were within scope of the contract and who the correct party to be claimed against.
# In terms of contractual claims pertaining to liquidated damages, I have been able to advise clients about the correct calculation of liquidated damages and whether the claimant was entitled to claim additional damages after the liquidated period had ended.
# In terms of extensions to the contract, I have been able to advise clients about the correct calculation of extensions and whether the contract allowed for the claimed extensions.
# In terms of extra work orders, I have been able to advise clients about the correct calculation of claimed variations and whether the claimed rates were in line with current market rates.
# In terms of interim payments, I have been able to advise clients about the correct calculation of retention release and whether the contract allowed for the claimed retention period.
# In terms of project set-up,
# ==========
# Prompt: 264 tokens, 643.068 tokens-per-sec
# Generation: 400 tokens, 25.764 tokens-per-sec
# Peak memory: 14.654 GB

# %% [markdown]
# ### Step 4.3: Inferencing the fused fine-tuned model using the MLX community guidelines
#
# This step is optional. I included it within my code to showcase how you can use the fused MLX Fine-tuned model with its trained adapters inside a python environment using the MLX community Huggingface guidelines.
#
# You can refer to the location of the fine-tuned model which contains the safetensors for the model weights, the tokenizers, the configuration and other relevant files that are necessary for inferencing.
#
# You can tweak the prompt however you see fit. It could be a list of prompts that need to be dealt with in one hit.

# %%
# Import required MLX libraries for model loading and text generation
from mlx_lm import load, generate

# Remove single quotes from the model path string
# This ensures proper path formatting for model loading
fine_tuned_mlx_model = output_directory.strip("'")

# Load the fine-tuned model and its associated tokenizer
# model: The neural network model with merged weights
# tokenizer: Handles text tokenization and detokenization
model, tokenizer = load(fine_tuned_mlx_model)

# Define the input prompt requesting a specific RICS APC competency example
prompt="Give me a good quality quality example of competency: Construction Technology level 3"

# Check if the tokenizer has chat template capabilities
# This ensures proper formatting for chat-based models
if hasattr(tokenizer, "apply_chat_template") and tokenizer.chat_template is not None:
   # Create a messages list with user role and content
   messages = [{"role": "user", "content": prompt}]
   
   # Apply the model's chat template to format the prompt
   # tokenize=False: Returns string instead of tokens
   # add_generation_prompt=True: Adds any necessary generation markers
   prompt = tokenizer.apply_chat_template(
       messages, tokenize=False, add_generation_prompt=True
   )

# Generate response using the model
# model: The loaded MLX model
# tokenizer: For converting between tokens and text
# prompt: The formatted input prompt
# verbose=True: Shows generation progress and details
response = generate(model, tokenizer, prompt=prompt, verbose=True)
# Out:
# ==========
# On a project related to the restoration of a historical grade II* listed building, I was the key contact for the client in terms of the cost implications of using traditional versus non-traditional construction methods. I provided the client with the relative pros and cons of using traditional and non-traditional methods, as well as providing examples of the key materials that would be used in both traditional and non-traditional methods, along with their relative costs. I advised the client that using traditional methods would significantly increase the cost of the project, which in turn affected their decision making process in favour of using non-traditional methods. I completed a cost comparison report outlining the cost of both options, which was provided to the client.
# ==========
# Prompt: 19 tokens, 145.607 tokens-per-sec
# Generation: 152 tokens, 25.455 tokens-per-sec
# Peak memory: 28.992 GB

# %% [markdown]
# ### Step 4.4: Exporting the model to Huggingface for further conversion to GGUF
#
# This step is optional. It tackles the process of saving LLMs on the Huggingface website which can then be transformed into a GGUF format using the **"GGUF my repo"** initiative on the Huggingface website.
#
# Once you have uploaded your fine-tuned model to your repository on the Huggingface website, you could go to https://huggingface.co/spaces/ggml-org/gguf-my-repo and then you could refer to your repository and choose what quantization level suits you the most.

# %%
# Command to Fuse and Upload Fine-tuned MLX Model to Hugging Face
# This process merges the base model with LoRA adaptations and uploads to HF hub

# --model ${mlx_path}
# Purpose: Specifies the base model path used during fine-tuning
# Example: Could be local path like "./mistral-7b-v0.1" or HF repo like "mistralai/Mistral-7B-v0.1"
# Note: This is the model you used as foundation for fine-tuning

# --adapter-path ${adapters}
# Purpose: Points to the trained LoRA adapter weights and configuration
# Example: "./adapters/final_weights.npz"
# Importance: Contains all the task-specific learning from fine-tuning

# --hf-path ${hf_model}
# Purpose: Path to original Hugging Face model
# Required: When uploading a local model to HF hub
# Example: "mistralai/Mistral-7B-v0.1"
# Note: Ensures proper model card and metadata during upload

# --upload-repo ${hf_upload_repo}
# Purpose: Specifies destination repository on Hugging Face
# Format: "username/repo-name" or "organization/repo-name"
# Example: "mlx-community/mistral-7b-mlx-finetuned"
# Note: Requires HF authentication token to be set up

# --de-quantize
# Purpose: Converts model back to full precision
# Benefit: Maximizes model accuracy for sharing
# Trade-off: Increases model size
# Important: Common practice when sharing models publicly

# !mlx_lm.fuse \
    --model ${mlx_path} \
    --adapter-path ${adapters} \
    --hf-path ${hf_model} \
    --upload-repo ${hf_upload_repo} \
    --de-quantize

# Note: After execution:
# 1. Model will be merged with adapters
# 2. Converted to full precision
# 3. Uploaded to specified HF repository
# 4. Model card and files will be available publicly
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Loading pretrained model
# De-quantizing model
# README.md: 100%|███████████████████████████| 7.82k/7.82k [00:00<00:00, 17.3MB/s]
# Repo created: https://huggingface.co/MohamedAshour1993/RICS_APC_Mistral-7B-Instruct-v0.3_MLX
# Found 10 candidate files to upload
# Recovering from metadata files: 100%|█████████| 10/10 [00:00<00:00, 2742.81it/s]
#
#
#
# ---------- 2025-02-04 07:46:31 (0:00:00) ----------
# Files:   hashed 6/10 (755.6K/14.5G) | pre-uploaded: 0/0 (0.0/14.5G) (+10 unsure) | committed: 0/10 (0.0/14.5G) | ignored: 0
# Workers: hashing: 7 | get upload mode: 3 | pre-uploading: 0 | committing: 0 | waiting: 4
# ---------------------------------------------------
# tokenizer.model: 100%|████████████████████████| 587k/587k [00:00<00:00, 924kB/s]
# model-00003-of-00003.safetensors:   0%|    | 9.57M/3.88G [00:00<04:51, 13.3MB/s]
# model-00003-of-00003.safetensors:   0%|    | 11.1M/3.88G [00:00<04:42, 13.7MB/s]
# model-00001-of-00003.safetensors:   0%|   | 147k/5.27G [00:00<1:09:17, 1.27MB/s]
#
# model-00003-of-00003.safetensors:   0%|    | 12.6M/3.88G [00:00<04:39, 13.8MB/s]
# model-00001-of-00003.safetensors:   0%|     | 360k/5.27G [00:00<54:22, 1.61MB/s]
#
# model-00003-of-00003.safetensors:   0%|    | 14.1M/3.88G [00:01<04:51, 13.3MB/s]
# model-00001-of-00003.safetensors:   0%|     | 786k/5.27G [00:00<33:26, 2.63MB/s]
#
# model-00002-of-00003.safetensors:   0%|   | 262k/5.35G [00:00<1:19:46, 1.12MB/s]
#
# model-00002-of-00003.safetensors:   0%|    | 377k/5.35G [00:00<1:37:39, 913kB/s]
# model-00001-of-00003.safetensors:   0%|    | 1.29M/5.27G [00:00<49:33, 1.77MB/s]
#
# model-00002-of-00003.safetensors:   0%|    | 475k/5.35G [00:00<2:42:53, 548kB/s]
# model-00001-of-00003.safetensors:   0%|    | 1.52M/5.27G [00:00<53:34, 1.64MB/s]
#
# model-00002-of-00003.safetensors:   0%|   | 934k/5.35G [00:00<1:03:10, 1.41MB/s]
# model-00003-of-00003.safetensors:   0%|    | 15.5M/3.88G [00:01<12:36, 5.10MB/s]
#
# model-00002-of-00003.safetensors:   0%|    | 1.49M/5.35G [00:00<37:47, 2.36MB/s]
# model-00001-of-00003.safetensors:   0%|    | 2.05M/5.27G [00:01<43:41, 2.01MB/s]
#
# model-00002-of-00003.safetensors:   0%|    | 2.06M/5.35G [00:01<27:57, 3.19MB/s]
# model-00001-of-00003.safetensors:   0%|    | 2.41M/5.27G [00:01<36:49, 2.38MB/s]
#
# model-00002-of-00003.safetensors:   0%|    | 2.70M/5.35G [00:01<22:36, 3.94MB/s]
# model-00001-of-00003.safetensors:   0%|    | 2.88M/5.27G [00:01<29:34, 2.97MB/s]
#
# model-00002-of-00003.safetensors:   0%|    | 3.47M/5.35G [00:01<18:20, 4.86MB/s]
# model-00001-of-00003.safetensors:   0%|    | 3.38M/5.27G [00:01<25:32, 3.43MB/s]
#
# model-00003-of-00003.safetensors:   0%|    | 16.5M/3.88G [00:02<16:24, 3.92MB/s]
# model-00001-of-00003.safetensors:   0%|    | 3.80M/5.27G [00:01<23:59, 3.66MB/s]
#
# model-00002-of-00003.safetensors:   0%|    | 4.73M/5.35G [00:01<16:18, 5.46MB/s]
# model-00003-of-00003.safetensors:   0%|    | 17.3M/3.88G [00:02<16:13, 3.96MB/s]
#
# model-00002-of-00003.safetensors:   0%|    | 5.37M/5.35G [00:01<15:34, 5.72MB/s]
# model-00001-of-00003.safetensors:   0%|    | 4.83M/5.27G [00:01<20:16, 4.33MB/s]
#
# model-00002-of-00003.safetensors:   0%|    | 6.00M/5.35G [00:01<15:37, 5.70MB/s]
# model-00003-of-00003.safetensors:   0%|    | 18.0M/3.88G [00:02<16:10, 3.98MB/s]
#
# model-00002-of-00003.safetensors:   0%|    |
B/s]
#
# model-00002-of-00003.safetensors:  99%|███▉| 5.32G/5.35G [17:56<00:04, 7.12MB/s]
# model-00001-of-00003.safetensors: 100%|███▉| 5.26G/5.27G [17:56<00:00, 5.58MB/s]
#
# model-00002-of-00003.safetensors:  99%|███▉| 5.32G/5.35G [17:56<00:03, 8.02MB/s]
# model-00001-of-00003.safetensors: 100%|███▉| 5.27G/5.27G [17:56<00:00, 6.11MB/s]
#
# model-00002-of-00003.safetensors:  99%|███▉| 5.32G/5.35G [17:56<00:03, 7.77MB/s]
# model-00001-of-00003.safetensors: 100%|███▉| 5.27G/5.27G [17:56<00:00, 6.40MB/s]
#
# model-00002-of-00003.safetensors:  99%|███▉| 5.32G/5.35G [17:56<00:03, 7.64MB/s]
# model-00001-of-00003.safetensors: 100%|███▉| 5.27G/5.27G [17:57<00:00, 6.78MB/s]
#
# model-00002-of-00003.safetensors:  99%|███▉| 5.33G/5.35G [17:56<00:03, 7.61MB/s]
# model-00001-of-00003.safetensors: 100%|███▉| 5.27G/5.27G [17:57<00:00, 7.02MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.33G/5.35G [17:57<00:03, 7.46MB/s]
#
# model-00001-of-00003.safetensors: 100%|████| 5.27G/5.27G [17:57<00:00, 4.89MB/s]
#
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.33G/5.35G [17:57<00:04, 5.78MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.33G/5.35G [17:57<00:02, 8.16MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.33G/5.35G [17:57<00:02, 9.58MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.33G/5.35G [17:57<00:01, 10.7MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.33G/5.35G [17:57<00:01, 11.6MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.34G/5.35G [17:57<00:01, 12.0MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.34G/5.35G [17:58<00:01, 12.8MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.34G/5.35G [17:58<00:01, 13.5MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.34G/5.35G [17:58<00:00, 13.6MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.34G/5.35G [17:58<00:00, 13.9MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.34G/5.35G [17:58<00:00, 14.0MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.34G/5.35G [17:58<00:00, 10.8MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.35G/5.35G [17:58<00:00, 12.5MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.35G/5.35G [17:58<00:00, 12.9MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.35G/5.35G [17:58<00:00, 13.4MB/s]
#
# model-00002-of-00003.safetensors: 100%|███▉| 5.35G/5.35G [17:59<00:00, 13.8MB/s]
#
# model-00002-of-00003.safetensors: 100%|████| 5.35G/5.35G [17:59<00:00, 4.96MB/s]
#
# ---------- 2025-02-04 08:04:35 (0:18:04) ----------
# Files:   hashed 10/10 (14.5G/14.5G) | pre-uploaded: 4/4 (14.5G/14.5G) | committed: 0/10 (0.0/14.5G) | ignored: 0
# Workers: hashing: 0 | get upload mode: 0 | pre-uploading: 0 | committing: 1 | waiting: 13
# ---------------------------------------------------
#                              All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
# All files have been processed! Exiting worker.
# INFO:huggingface_hub._upload_large_folder:All files have been processed! Exiting worker.
#
# ---------- 2025-02-04 08:04:42 (0:18:11) ----------
# Files:   hashed 10/10 (14.5G/14.5G) | pre-uploaded: 4/4 (14.5G/14.5G) | committed: 10/10 (14.5G/14.5G) | ignored: 0
# Workers: hashing: 0 | get upload mode: 0 | pre-uploading: 0 | committing: 0 | waiting: 0
# ---------------------------------------------------
# INFO:huggingface_hub._upload_large_folder:
# ---------- 2025-02-04 08:04:42 (0:18:11) ----------
# Files:   hashed 10/10 (14.5G/14.5G) | pre-uploaded: 4/4 (14.5G/14.5G) | committed: 10/10 (14.5G/14.5G) | ignored: 0
# Workers: hashing: 0 | get upload mode: 0 | pre-uploading: 0 | committing: 0 | waiting: 0
# ---------------------------------------------------
# Upload successful, go to https://huggingface.co/MohamedAshour1993/RICS_APC_Mistral-7B-Instruct-v0.3_MLX for details.

# %% [markdown]
# ### Step 4.5: Converting the fused finetuned model with the Low Rank Adaptors using llama.cpp
#
# In this step we are going to use the functionality of converting huggingface models to GGUF under the llama.cpp.
#
# To do that we have to open the terminal where llama.cpp is saved. We can do that by going to the folder where llama.cpp is cloned and then right click on the pathname bar and choose the option "Open in Terminal".
#
# This will open a terminal instance in the folder llama.cpp is cloned. We can then make the best use of the conver_hf_to_gguf python file available in this directory for our conversion process.
#
# For the purpose of this notebook, I have saved the location where llama.cpp is cloned on my machine in a variable called "llama_cpp_path" which you could find in Part III , Step 3.1 above.
#
# This conversion to GGUF is important in case we are going to use the models in third party applications such as Ollama and Open WebUI.

# %%
#Understanding the arguments within the llama.cpp convert huggingface models to gguf

# %cd {llama_cpp_path}

# !python3 convert_hf_to_gguf.py --help
# Out:
# /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/llama.cpp
# /Users/mohamedraouf/Library/Python/3.11/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# usage: convert_hf_to_gguf.py [-h] [--vocab-only] [--outfile OUTFILE]
#                              [--outtype {f32,f16,bf16,q8_0,tq1_0,tq2_0,auto}]
#                              [--bigendian] [--use-temp-file] [--no-lazy]
#                              [--model-name MODEL_NAME] [--verbose]
#                              [--split-max-tensors SPLIT_MAX_TENSORS]
#                              [--split-max-size SPLIT_MAX_SIZE] [--dry-run]
#                              [--no-tensor-first-split] [--metadata METADATA]
#                              [--print-supported-models]
#                              [model]
#
# Convert a huggingface model to a GGML compatible file
#
# positional arguments:
#   model                 directory containing model file
#
# options:
#   -h, --help            show this help message and exit
#   --vocab-only          extract only the vocab
#   --outfile OUTFILE     path to write to; default: based on input. {ftype}
#                         will be replaced by the outtype.
#   --outtype {f32,f16,bf16,q8_0,tq1_0,tq2_0,auto}
#                         output format - use f32 for float32, f16 for float16,
#                         bf16 for bfloat16, q8_0 for Q8_0, tq1_0 or tq2_0 for
#                         ternary, and auto for the highest-fidelity 16-bit
#                         float type depending on the first loaded tensor type
#   --bigendian           model is executed on big endian machine
#   --use-temp-file       use the tempfile library while processing (helpful
#                         when running out of memory, process killed)
#   --no-lazy             use more RAM by computing all outputs before writing
#                         (use in case lazy evaluation is broken)
#   --model-name MODEL_NAME
#                         name of the model
#   --verbose             increase output verbosity
#   --split-max-tensors SPLIT_MAX_TENSORS
#                         max tensors in each split
#   --split-max-size SPLIT_MAX_SIZE
#                         max size per split N(M|G)
#   --dry-run             only print out a split plan and exit, without writing
#                         any new files
#   --no-tensor-first-split
#                         do not add tensors to the first split (disabled by
#                         default)
#   --metadata METADATA   Specify the path for an authorship metadata override
#                         file
#   --print-supported-models
#                         Print the supported models

# %%
# In the following block of code, I am focusing on the following:
#----------------------------------------------------------------
# 1. Referring to the location where I saved my fine-tuned model
# 2. Referring to the location of where I want to save the resultant GGUF model 
# 3. Stating explicitly what level of quantization is required. You can refer to the explanation of the code arguments in the previous code block.
# 4. Using the no lazy which forces immediate loading of all model weights instead of loading them when needed, ensuring complete model validation upfront
# 5. I am also enabling the verbose option which enables detailed output logging during conversion, showing step-by-step progress and additional information

# !python3 convert_hf_to_gguf.py \
    {output_directory} \
    --outfile {output_directory} \
    --outtype q8_0 \
    --no-lazy \
    --verbose
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# INFO:hf-to-gguf:Loading model: Mistral-7B-Instruct-v0.3_MLX_Finetuned
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'model-00001-of-00003.safetensors'
# INFO:hf-to-gguf:token_embd.weight,           torch.float16 --> Q8_0, shape = {4096, 32768}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,       torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,       torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,         torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,       torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.0.attn_k.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.0.attn_output.weight,    torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.0.attn_q.weight,         torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.0.attn_v.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.1.attn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.1.ffn_down.weight,       torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight,       torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.1.ffn_up.weight,         torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.1.ffn_norm.weight,       torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.1.attn_k.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.1.attn_output.weight,    torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.1.attn_q.weight,         torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.1.attn_v.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.10.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.10.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.10.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.10.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.10.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.10.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.10.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.10.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.11.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.11.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.11.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.11.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.2.attn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.2.ffn_down.weight,       torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight,       torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.2.ffn_up.weight,         torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.2.ffn_norm.weight,       torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.2.attn_k.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.2.attn_output.weight,    torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.2.attn_q.weight,         torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.2.attn_v.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.3.attn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.3.ffn_down.weight,       torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight,       torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.3.ffn_up.weight,         torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.3.ffn_norm.weight,       torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.3.attn_k.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.3.attn_output.weight,    torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.3.attn_q.weight,         torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.3.attn_v.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.4.attn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.4.ffn_down.weight,       torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight,       torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.4.ffn_up.weight,         torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.4.ffn_norm.weight,       torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.4.attn_k.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.4.attn_output.weight,    torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.4.attn_q.weight,         torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.4.attn_v.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.5.attn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.5.ffn_down.weight,       torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight,       torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.5.ffn_up.weight,         torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.5.ffn_norm.weight,       torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.5.attn_k.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.5.attn_output.weight,    torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.5.attn_q.weight,         torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.5.attn_v.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.6.attn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.6.ffn_down.weight,       torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight,       torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.6.ffn_up.weight,         torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.6.ffn_norm.weight,       torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.6.attn_k.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.6.attn_output.weight,    torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.6.attn_q.weight,         torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.6.attn_v.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.7.attn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.7.ffn_down.weight,       torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.7.ffn_gate.weight,       torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.7.ffn_up.weight,         torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.7.ffn_norm.weight,       torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.7.attn_k.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.7.attn_output.weight,    torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.7.attn_q.weight,         torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.7.attn_v.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.8.attn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.8.ffn_down.weight,       torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.8.ffn_gate.weight,       torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.8.ffn_up.weight,         torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.8.ffn_norm.weight,       torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.8.attn_k.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.8.attn_output.weight,    torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.8.attn_q.weight,         torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.8.attn_v.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.9.attn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.9.ffn_down.weight,       torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.9.ffn_gate.weight,       torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.9.ffn_up.weight,         torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.9.ffn_norm.weight,       torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.9.attn_k.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.9.attn_output.weight,    torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.9.attn_q.weight,         torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.9.attn_v.weight,         torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00002-of-00003.safetensors'
# INFO:hf-to-gguf:blk.11.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.11.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.11.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.11.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.12.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.12.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.12.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.12.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.12.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.12.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.12.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.12.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.13.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.13.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.13.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.13.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.13.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.13.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.13.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.13.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.14.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.14.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.14.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.14.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.14.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.14.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.14.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.14.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.15.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.15.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.15.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.15.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.15.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.15.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.15.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.15.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.16.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.16.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.16.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.16.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.16.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.16.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.16.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.16.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.16.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.17.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.17.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.17.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.17.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.17.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.17.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.17.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.17.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.17.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.18.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.18.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.18.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.18.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.18.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.18.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.18.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.18.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.18.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.19.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.19.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.19.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.19.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.19.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.19.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.19.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.19.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.19.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.20.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.20.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.20.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.20.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.20.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.20.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.20.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.20.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.20.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.21.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.21.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.21.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.21.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.21.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.21.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.21.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.21.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.21.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.22.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.22.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.22.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.22.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.22.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.22.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.22.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.22.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.22.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.23.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.23.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.23.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.23.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.23.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.23.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00003-of-00003.safetensors'
# INFO:hf-to-gguf:output.weight,               torch.float16 --> Q8_0, shape = {4096, 32768}
# INFO:hf-to-gguf:blk.23.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.23.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.23.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.24.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.24.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.24.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.24.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.24.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.24.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.24.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.24.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.24.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.25.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.25.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.25.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.25.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.25.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.25.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.25.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.25.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.25.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.26.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.26.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.26.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.26.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.26.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.26.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.26.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.26.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.26.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.27.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.27.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.27.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.27.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.27.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.27.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.27.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.27.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.27.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.28.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.28.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.28.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.28.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.28.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.28.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.28.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.28.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.28.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.29.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.29.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.29.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.29.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.29.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.29.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.29.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.29.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.29.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.30.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.30.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.30.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.30.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.30.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.30.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.30.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.30.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.30.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.31.attn_norm.weight,     torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.31.ffn_down.weight,      torch.float16 --> Q8_0, shape = {14336, 4096}
# INFO:hf-to-gguf:blk.31.ffn_gate.weight,      torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.31.ffn_up.weight,        torch.float16 --> Q8_0, shape = {4096, 14336}
# INFO:hf-to-gguf:blk.31.ffn_norm.weight,      torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.31.attn_k.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:blk.31.attn_output.weight,   torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.31.attn_q.weight,        torch.float16 --> Q8_0, shape = {4096, 4096}
# INFO:hf-to-gguf:blk.31.attn_v.weight,        torch.float16 --> Q8_0, shape = {4096, 1024}
# INFO:hf-to-gguf:output_norm.weight,          torch.float16 --> F32, shape = {4096}
# INFO:hf-to-gguf:Set meta model
# INFO:hf-to-gguf:Set model parameters
# INFO:hf-to-gguf:gguf: context length = 32768
# INFO:hf-to-gguf:gguf: embedding length = 4096
# INFO:hf-to-gguf:gguf: feed forward length = 14336
# INFO:hf-to-gguf:gguf: head count = 32
# INFO:hf-to-gguf:gguf: key-value head count = 8
# INFO:hf-to-gguf:gguf: rope theta = 1000000.0
# INFO:hf-to-gguf:gguf: rms norm epsilon = 1e-05
# INFO:hf-to-gguf:gguf: file type = 7
# INFO:hf-to-gguf:Set model tokenizer
# INFO:gguf.vocab:Setting special token type bos to 1
# INFO:gguf.vocab:Setting special token type eos to 2
# INFO:gguf.vocab:Setting special token type unk to 0
# INFO:gguf.vocab:Setting add_bos_token to True
# INFO:gguf.vocab:Setting add_eos_token to False
# INFO:gguf.vocab:Setting chat_template to {%- if messages[0]["role"] == "system" %}
#     {%- set system_message = messages[0]["content"] %}
#     {%- set loop_messages = messages[1:] %}
# {%- else %}
#     {%- set loop_messages = messages %}
# {%- endif %}
# {%- if not tools is defined %}
#     {%- set tools = none %}
# {%- endif %}
# {%- set user_messages = loop_messages | selectattr("role", "equalto", "user") | list %}
#
# {#- This block checks for alternating user/assistant messages, skipping tool calling messages #}
# {%- set ns = namespace() %}
# {%- set ns.index = 0 %}
# {%- for message in loop_messages %}
#     {%- if not (message.role == "tool" or message.role == "tool_results" or (message.tool_calls is defined and message.tool_calls is not none)) %}
#         {%- if (message["role"] == "user") != (ns.index % 2 == 0) %}
#             {{- raise_exception("After the optional system message, conversation roles must alternate user/assistant/user/assistant/...") }}
#         {%- endif %}
#         {%- set ns.index = ns.index + 1 %}
#     {%- endif %}
# {%- endfor %}
#
# {{- bos_token }}
# {%- for message in loop_messages %}
#     {%- if message["role"] == "user" %}
#         {%- if tools is not none and (message == user_messages[-1]) %}
#             {{- "[AVAILABLE_TOOLS] [" }}
#             {%- for tool in tools %}
#                 {%- set tool = tool.function %}
#                 {{- '{"type": "function", "function": {' }}
#                 {%- for key, val in tool.items() if key != "return" %}
#                     {%- if val is string %}
#                         {{- '"' + key + '": "' + val + '"' }}
#                     {%- else %}
#                         {{- '"' + key + '": ' + val|tojson }}
#                     {%- endif %}
#                     {%- if not loop.last %}
#                         {{- ", " }}
#                     {%- endif %}
#                 {%- endfor %}
#                 {{- "}}" }}
#                 {%- if not loop.last %}
#                     {{- ", " }}
#                 {%- else %}
#                     {{- "]" }}
#                 {%- endif %}
#             {%- endfor %}
#             {{- "[/AVAILABLE_TOOLS]" }}
#             {%- endif %}
#         {%- if loop.last and system_message is defined %}
#             {{- "[INST] " + system_message + "\n\n" + message["content"] + "[/INST]" }}
#         {%- else %}
#             {{- "[INST] " + message["content"] + "[/INST]" }}
#         {%- endif %}
#     {%- elif message.tool_calls is defined and message.tool_calls is not none %}
#         {{- "[TOOL_CALLS] [" }}
#         {%- for tool_call in message.tool_calls %}
#             {%- set out = tool_call.function|tojson %}
#             {{- out[:-1] }}
#             {%- if not tool_call.id is defined or tool_call.id|length != 9 %}
#                 {{- raise_exception("Tool call IDs should be alphanumeric strings with length 9!") }}
#             {%- endif %}
#             {{- ', "id": "' + tool_call.id + '"}' }}
#             {%- if not loop.last %}
#                 {{- ", " }}
#             {%- else %}
#                 {{- "]" + eos_token }}
#             {%- endif %}
#         {%- endfor %}
#     {%- elif message["role"] == "assistant" %}
#         {{- " " + message["content"]|trim + eos_token}}
#     {%- elif message["role"] == "tool_results" or message["role"] == "tool" %}
#         {%- if message.content is defined and message.content.content is defined %}
#             {%- set content = message.content.content %}
#         {%- else %}
#             {%- set content = message.content %}
#         {%- endif %}
#         {{- '[TOOL_RESULTS] {"content": ' + content|string + ", " }}
#         {%- if not message.tool_call_id is defined or message.tool_call_id|length != 9 %}
#             {{- raise_exception("Tool call IDs should be alphanumeric strings with length 9!") }}
#         {%- endif %}
#         {{- '"call_id": "' + message.tool_call_id + '"}[/TOOL_RESULTS]' }}
#     {%- else %}
#         {{- raise_exception("Only user and assistant roles are supported, with the exception of an initial optional system message!") }}
#     {%- endif %}
# {%- endfor %}
#
# INFO:hf-to-gguf:Set model quantization version
# INFO:gguf.gguf_writer:Writing the following files:
# INFO:gguf.gguf_writer:/Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/RICS_APC_Finetuning/Mistral-7B-Instruct-v0.3_MLX_Finetuned/Mistral-7B-Instruct-v0.3_MLX_Finetuned-Q8_0.gguf: n_tensors = 291, total_size = 7.7G
# Writing: 100%|██████████████████████████| 7.70G/7.70G [00:01<00:00, 6.72Gbyte/s]
# INFO:hf-to-gguf:Model successfully exported to /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/RICS_APC_Finetuning/Mistral-7B-Instruct-v0.3_MLX_Finetuned/Mistral-7B-Instruct-v0.3_MLX_Finetuned-Q8_0.gguf

# %% [markdown]
# ### Step 4.6: Exporting the Fine-tuned model with GGUF to Ollama for further usage using the Ollama API
#
# In this step, I am creating a model file for the fine-tuned MLX Mistral model, taking into account its architecture.
#
# Every model has different architecture. One has to respect the prompting architecture in order to get meaningful inferencing.
#
# I created the model file taking into account how the parameters, the template and the system prompt should be tweaked for the Mistral Architecture.
#
# In order to create a model file, you can create an empty txt file and then make sure to remove its extension. I have named mine "ModelFile"
#
# The next block contains the created Model File.

# %% [markdown]
# ##### Here is my Model File for the Mistal Instruct v0.3 fine-tuned model via MLX
# ------
# **1 - From: You have to state the directory where your gguf file is saved so that the model file can relate to it.**
#
# from /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/RICS_APC_Finetuning/Mistral-7B-Instruct-v0.3_MLX_Finetuned/Mistral-7B-Instruct-v0.3_MLX_Finetuned-Q8_0.gguf
# _________
# **2 - Parameters:**
#
# * **Here you can type in the parameters that you want to include within your model architecure.**
# * **I have also included the start and stop tokens that can help the model produce meaningful responses and not to produce text indefinitely.**
#
# parameter temperature 0.2
# parameter num_ctx 4096
#
# parameter stop [INST]
# parameter stop [/INST]
# _____________
#
# **3 - Template:**
# * **The template allows for meaningful chats with the model. You can see how the chat is display by displaying the model template card on Ollama's website.**
# * **The template that is used below is for the Mistral Architecture.**
#
# template """
#
# {{- if .Messages }}
# {{- range $index, $_ := .Messages }}
# {{- if eq .Role "user" }}
# {{- if and (eq (len (slice $.Messages $index)) 1) $.Tools }}[AVAILABLE_TOOLS] {{ $.Tools }}[/AVAILABLE_TOOLS]
# {{- end }}[INST] {{ if and $.System (eq (len (slice $.Messages $index)) 1) }}{{ $.System }}
#
# {{ end }}{{ .Content }}[/INST]
# {{- else if eq .Role "assistant" }}
# {{- if .Content }} {{ .Content }}
# {{- else if .ToolCalls }}[TOOL_CALLS] [
# {{- range .ToolCalls }}{"name": "{{ .Function.Name }}", "arguments": {{ .Function.Arguments }}}
# {{- end }}]
# {{- end }}</s>
# {{- else if eq .Role "tool" }}[TOOL_RESULTS] {"content": {{ .Content }}} [/TOOL_RESULTS]
# {{- end }}
# {{- end }}
# {{- else }}[INST] {{ if .System }}{{ .System }}
#
# {{ end }}{{ .Prompt }}[/INST]
# {{- end }} {{ .Response }}
# {{- if .Response }}</s>
# {{- end }}
#
# """
# ___________________________
#
# **4- System Prompt:**
# * **I have chosen to include a system prompt to make the responses provided by the model quite relevant to its use-case and also aiming to reduce hallucination.**
# * **System Prompts can also allow more control over the model in the way it behaves, where it gets its information from, what are the boundaries,..etc**
#
# system """ You are an AI language model specialized in providing detailed, accurate, and professional responses to questions related to the RICS Assessment of Professional Competence (APC). Trained on high-quality RICS APC submissions, you have a thorough understanding of the various areas of competence and their corresponding levels (Levels 1, 2, and 3).
#
# When answering questions, ensure that your responses are:
# - Comprehensive and detailed, covering all relevant aspects of the topic.
# - Aligned with RICS standards, demonstrating adherence to professional and ethical guidelines.
# - Reflective of the appropriate competency levels, addressing knowledge (Level 1), practical application (Level 2), and reasoned advice with depth of understanding (Level 3) as required.
# - Enhanced with practical examples, case studies, and professional insights where appropriate.
# - Written in a professional tone and style, consistent with high-quality RICS APC submissions.
#
# Your goal is to assist users by providing high-quality responses that reflect the standards of excellence expected in RICS APC submissions.
# """

# %%
# In this block of code, I am exporting the MLX fine-tuned model to Ollama using the model file generated in the code block above.
# In order to export a model to ollama, you have to open the terminal where the gguf file is stored.
# We can do that by going to the folder where the gguf file is stored and then right click on the comprising folder on the pathname bar and choose the option "Open in Terminal".
# For the purpose of this notebook, I have kept it simple. I stored the directory where the gguf file is saved in a variable called "output_directory". You can check the full list of variables in Part III, Step 3.6 above.
# The export option could be done using the code : ollama create {Your_Desired_Model_Name} -f ModelFile

# %cd {output_directory}

! ollama create {Desired_model_name} -f ModelFile
# Out:
# /Users/mohamedraouf/Documents/Dossiers du travail/Technical Excellence/LLMs training/MacOS_LLM_Finetuning/RICS_APC_Finetuning/Mistral-7B-Instruct-v0.3_MLX_Finetuned
# /Users/mohamedraouf/Library/Python/3.11/lib/python/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# gathering model components ⠙ gathering model components ⠙ gathering model components ⠸ gathering model components ⠼ gathering model components ⠴ gathering model components ⠴ gathering model components ⠧ gathering model components ⠇ gathering model components ⠏ gathering model components ⠋ gathering model components ⠙ gathering model components ⠙ gathering model components ⠸ gathering model components ⠼ gathering model components ⠴ gathering model components ⠦ gathering model components ⠧ gathering model components ⠇ gathering model components ⠏ gathering model components ⠋ gathering model components ⠋ gathering model components ⠹ gathering model components ⠹ gathering model components ⠼ gathering model components ⠼ gathering model components ⠴ gathering model components ⠦ gathering model components ⠇ gathering model components ⠏ gathering model components ⠋ gathering model components
# copying file sha256:f5e4025b4f49795c0471cea6e7fad27b7fff312979ab4094459d12c3e7fa809c 100%
# parsing GGUF ⠋ gathering model components
# copying file sha256:f5e4025b4f49795c0471cea6e7fad27b7fff312979ab4094459d12c3e7fa809c 100%
# parsing GGUF ⠙ gathering model components
# copying file sha256:f5e4025b4f49795c0471cea6e7fad27b7fff312979ab4094459d12c3e7fa809c 100%
# parsing GGUF
# using existing layer sha256:f5e4025b4f49795c0471cea6e7fad27b7fff312979ab4094459d12c3e7fa809c
# creating new layer sha256:52cd269aa95300e83751625f32a5c840932ae87596a48ad0841c278ac9c3f364
# creating new layer sha256:bee956aac035ec525ec973e0ea192874d049b0b73f4e68843850a9a521a9efbc
# creating new layer sha256:962943f5a5b075e33cc9bdda81e787633f730d9d761af6df45c95fcfa4e31caf
# writing manifest
# success

# %%
# !ollama list
# Out:
# NAME                                                              ID              SIZE      MODIFIED
# RICS_APC_Mistral-7B-Instruct-v0.3_MLX_Finetuned_GGUF_Q8:latest    2820d7985118    7.7 GB    12 seconds ago
# llama3.2:3b                                                       a80c4f17acd5    2.0 GB    34 hours ago
# all-minilm:latest                                                 1b226e2802db    45 MB     34 hours ago
# mxbai-embed-large:latest                                          468836162de7    669 MB    34 hours ago
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
